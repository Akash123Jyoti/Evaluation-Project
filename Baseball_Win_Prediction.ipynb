# %% [markdown]
# Problem Statement :
#   -  There are 16 different features that will be used as the inputs to the machine learning and the output will be a value that represents the number of wins.
#         - To predict the number of wins.

# %% [markdown]
# Columns Description :
# 1.	W - This indicates the number of Wins credited to a pitcher: number of games where pitcher was pitching while their team took the lead and went on to win, also the starter needs to pitch at least 5 innings of work.
# 2.	R - This indicates Runs scored. A run is scored when a player advances around first, second and third base and returns safely to home plate, touching the bases in that order, before three outs are recorded and all obligations to reach base safely on batted balls are met or assured: number of times a player crosses home plate.
# 3.	AB - This means At bat or time at bat. It's is a batter's turn batting against a pitcher: plate appearances, not including bases on balls, being hit by pitch, sacrifices, interference, or obstruction.
# 4.	H - This means Hit. It's also called a "base hit", is credited to a batter when the batter safely reaches or passes first base after hitting the ball into fair territory, without the benefit of either an error or a fielder's choice: reaching base because of a batted, fair ball without error by the defense.
# 5.	2B - This means the act of a batter striking the pitched ball and safely reaching second base without being called out by the umpire, without the benefit of a fielder's misplay (see error) or another runner being put out on a fielder's choice. A double is a type of hit (the others being the single, triple and home run) and is sometimes called a "two-bagger" or "two-base hit": hits on which the batter reaches second base safely without the contribution of a fielding error.
# 6.	3B - This measns a Triple.It's is the act of a batter safely reaching third base after hitting the ball, with neither the benefit of a fielder's misplay nor another runner being put out on a fielder's choice. A triple is sometimes called a "three-bagger" or "three-base hit": hits on which the batter reaches third base safely without the contribution of a fielding error.
# 7.	HR - This means Home runs. It's scored when the ball is hit in such a way that the batter is able to circle the bases and reach home plate safely in one play without any errors being committed by the defensive team. A home run is usually achieved by hitting the ball over the outfield fence between the foul poles (or hitting either foul pole) without the ball touching the field: hits on which the batter successfully touched all four bases, without the contribution of a fielding error.
# 8.	BB - This means Base on balls (also called a "walk"). It occurs in baseball when a batter receives four pitches that the umpire calls balls, and is in turn awarded first base without the possibility of being called out: hitter not swinging at four pitches called out of the strike zone and awarded first base.
# 9.	SO - Also denoted as "K" means Strikeout. It occurs when a batter accumulates three strikes during a time at bat. It usually means that the batter is out: number of batters who received strike three.
# 10.	SB - This means Stolen base. It occurs when a runner advances to a base to which they are not entitled and the official scorer rules that the advance should be credited to the action of the runner: number of bases advanced by the runner while the ball is in the possession of the defense.
# 11.	RA - This means Run Average. It refer to measures of the rate at which runs are allowed or scored.
# 12.	ER - This means Earned run. It refers to any run that was fully enabled by the offensive team's production in the face of competent play from the defensive team: number of runs that did not occur as a result of errors or passed balls.
# 13.	ERA - This means Earned Run Average. It refers to the average of earned runs allowed by a pitcher per nine innings pitched (i.e. the traditional length of a game). It is determined by dividing the number of earned runs allowed by the number of innings pitched and multiplying by nine: total number of earned runs (see "ER" above), multiplied by 9, divided by innings pitched.
# 14.	CG - This means Complete Game. It's the act of a pitcher pitching an entire game without the benefit of a relief pitcher. A pitcher who meets this criterion will be credited with a complete game regardless of the number of innings played: number of games where player was the only pitcher for their team.
# 15.	SHO - This means Shutout. It refers to the act by which a single pitcher pitches a complete game and does not allow the opposing team to score a run: number of complete games pitched with no runs allowed.
# 16.	SV - This means Save. It's credited to a pitcher who finishes a game for the winning team under certain prescribed circumstances: number of games where the pitcher enters a game led by the pitcher's team, finishes the game without surrendering the lead, is not the winning pitcher, and either (a) the lead was three runs or fewer when the pitcher entered the game; (b) the potential tying run was on base, at bat, or on deck; or (c) the pitcher pitched three or more innings.
# 17.	E - This means Errors. It's an act, in the judgment of the official scorer, of a fielder misplaying a ball in a manner that allows a batter or baserunner to advance one or more bases or allows a plate appearance to continue after the batter should have been put out. The term error is sometimes used to refer to the play during which an error was committed: number of times a fielder fails to make a play he should have made with common effort, and the offense benefits as a result.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


import warnings
warnings.filterwarnings('ignore')

# %%
baseball = pd.read_csv('https://raw.githubusercontent.com/dsrscientist/Data-Science-ML-Capstone-Projects/master/baseball.csv')

# %%
baseball
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 5    93  891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# 11   86  729  5459  1363  278  26  230  486  1392  121  618  572  3.57   5
# 12   85  661  5417  1331  243  21  176  435  1150   52  675  630  3.94   2
# 13   76  656  5544  1379  262  22  198  478  1336   69  726  677  4.16   6
# 14   68  694  5600  1405  277  46  146  475  1119   78  729  664  4.14   5
# 15  100  647  5484  1386  288  39  137  506  1267   69  525  478  2.94   1
# 16   98  697  5631  1462  292  27  140  461  1322   98  596  532  3.21   0
# 17   97  689  5491  1341  272  30  171  567  1518   95  608  546  3.36   6
# 18   68  655  5480  1378  274  34  145  412  1299   84  737  682  4.28   1
# 19   64  640  5571  1382  257  27  167  496  1255  134  754  700  4.33   2
# 20   90  683  5527  1351  295  17  177  488  1290   51  613  557  3.43   1
# 21   83  703  5428  1363  265  13  177  539  1344   57  635  577  3.62   4
# 22   71  613  5463  1420  236  40  120  375  1150  112  678  638  4.02   0
# 23   67  573  5420  1361  251  18  100  471  1107   69  760  698  4.41   3
# 24   63  626  5529  1374  272  37  130  387  1274   88  809  749  4.69   1
# 25   92  667  5385  1346  263  26  187  563  1258   59  595  553  3.44   6
# 26   84  696  5565  1486  288  39  136  457  1159   93  627  597  3.72   7
# 27   79  720  5649  1494  289  48  154  490  1312  132  713  659  4.04   1
# 28   74  650  5457  1324  260  36  148  426  1327   82  731  655  4.09   1
# 29   68  737  5572  1479  274  49  186  388  1283   97  844  799  5.04   4
#
#     SHO  SV    E
# 0     8  56   88
# 1    12  45   86
# 2    10  38   79
# 3     9  37  101
# 4    12  35   86
# 5    10  34   88
# 6     4  48   93
# 7    10  43   77
# 8    12  60   95
# 9    10  40   97
# 10    9  45  119
# 11   13  39   85
# 12   12  46   93
# 13   12  45   94
# 14   15  28  126
# 15   15  62   96
# 16   13  54  122
# 17   21  48  111
# 18    7  40  116
# 19    8  35   90
# 20   14  50   88
# 21   13  41   90
# 22   12  35   77
# 23   10  44   90
# 24    7  35  117
# 25   21  47   75
# 26   18  41   78
# 27   12  44   86
# 28    6  41   92
# 29    4  36   95

# %%
# Copy the original dataset to another object
df = baseball.copy()

# %%
# Show the first five rows of the dataframe
df.head()
# Out:
#     W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  \
# 0  95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2    8
# 1  83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2   12
# 2  81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11   10
# 3  76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7    9
# 4  74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7   12
#
#    SV    E
# 0  56   88
# 1  45   86
# 2  38   79
# 3  37  101
# 4  35   86

# %%
# Show the last five rows of the dataframe
df.tail()
# Out:
#      W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 25  92  667  5385  1346  263  26  187  563  1258   59  595  553  3.44   6
# 26  84  696  5565  1486  288  39  136  457  1159   93  627  597  3.72   7
# 27  79  720  5649  1494  289  48  154  490  1312  132  713  659  4.04   1
# 28  74  650  5457  1324  260  36  148  426  1327   82  731  655  4.09   1
# 29  68  737  5572  1479  274  49  186  388  1283   97  844  799  5.04   4
#
#     SHO  SV   E
# 25   21  47  75
# 26   18  41  78
# 27   12  44  86
# 28    6  41  92
# 29    4  36  95

# %%
# Show the dimension of the dataframe
print('The Shape of the Dataset is : ',df.shape)
# Out:
# The Shape of the Dataset is :  (30, 17)

# %% [markdown]
# - In the dataset there are only have 30 rows and 17 columns.

# %%
# Show the data types of the dataframe
print('The datatypes are : \n' + '*'*20)
print(df.dtypes)
# Out:
# The datatypes are :
# ********************
# W        int64
# R        int64
# AB       int64
# H        int64
# 2B       int64
# 3B       int64
# HR       int64
# BB       int64
# SO       int64
# SB       int64
# RA       int64
# ER       int64
# ERA    float64
# CG       int64
# SHO      int64
# SV       int64
# E        int64
# dtype: object

# %% [markdown]
# - Here it shows integer and float datatypes.

# %%
# Show the columns
df.columns.to_list()
# Out:
# ['W',
#  'R',
#  'AB',
#  'H',
#  '2B',
#  '3B',
#  'HR',
#  'BB',
#  'SO',
#  'SB',
#  'RA',
#  'ER',
#  'ERA',
#  'CG',
#  'SHO',
#  'SV',
#  'E']

# %%
# To check the missing value
print('Total Missing Values are : \n' + '*'*25)
print(df.isnull().sum())
# Out:
# Total Missing Values are :
# *************************
# W      0
# R      0
# AB     0
# H      0
# 2B     0
# 3B     0
# HR     0
# BB     0
# SO     0
# SB     0
# RA     0
# ER     0
# ERA    0
# CG     0
# SHO    0
# SV     0
# E      0
# dtype: int64

# %% [markdown]
# - From the above observation there is no missing value present in our dataset

# %%
# To check the duplicate value
print('Total Duplicate Values are : \n' + '*'*27)
print(df.duplicated().sum())
# Out:
# Total Duplicate Values are :
# ***************************
# 0

# %% [markdown]
# - By observation there do not have any duplicated value in our dataset

# %%
# To check the unique value
print('The Unique Values are : \n' + '*'*25)
df.nunique().to_frame('No. of unique value')
# Out:
# The Unique Values are :
# *************************
#      No. of unique value
# W                     24
# R                     28
# AB                    29
# H                     29
# 2B                    22
# 3B                    23
# HR                    27
# BB                    29
# SO                    29
# SB                    27
# RA                    30
# ER                    30
# ERA                   30
# CG                     9
# SHO                   12
# SV                    20
# E                     21

# %%
# Show the summary of dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 17 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   W       30 non-null     int64
#  1   R       30 non-null     int64
#  2   AB      30 non-null     int64
#  3   H       30 non-null     int64
#  4   2B      30 non-null     int64
#  5   3B      30 non-null     int64
#  6   HR      30 non-null     int64
#  7   BB      30 non-null     int64
#  8   SO      30 non-null     int64
#  9   SB      30 non-null     int64
#  10  RA      30 non-null     int64
#  11  ER      30 non-null     int64
#  12  ERA     30 non-null     float64
#  13  CG      30 non-null     int64
#  14  SHO     30 non-null     int64
#  15  SV      30 non-null     int64
#  16  E       30 non-null     int64
# dtypes: float64(1), int64(16)
# memory usage: 4.1 KB

# %%
# Show the statistical summary of data
df.describe()
# Out:
#                 W           R           AB            H          2B  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#               3B          HR          BB          SO          SB          RA  \
# count  30.000000   30.000000   30.000000    30.00000   30.000000   30.000000
# mean   31.300000  163.633333  469.100000  1248.20000   83.500000  688.233333
# std    10.452355   31.823309   57.053725   103.75947   22.815225   72.108005
# min    13.000000  100.000000  375.000000   973.00000   44.000000  525.000000
# 25%    23.000000  140.250000  428.250000  1157.50000   69.000000  636.250000
# 50%    31.000000  158.500000  473.000000  1261.50000   83.500000  695.500000
# 75%    39.000000  177.000000  501.250000  1311.50000   96.500000  732.500000
# max    49.000000  232.000000  570.000000  1518.00000  134.000000  844.000000
#
#                ER        ERA         CG        SHO         SV           E
# count   30.000000  30.000000  30.000000  30.000000  30.000000   30.000000
# mean   635.833333   3.956333   3.466667  11.300000  43.066667   94.333333
# std     70.140786   0.454089   2.763473   4.120177   7.869335   13.958889
# min    478.000000   2.940000   0.000000   4.000000  28.000000   75.000000
# 25%    587.250000   3.682500   1.000000   9.000000  37.250000   86.000000
# 50%    644.500000   4.025000   3.000000  12.000000  42.000000   91.000000
# 75%    679.250000   4.220000   5.750000  13.000000  46.750000   96.750000
# max    799.000000   5.040000  11.000000  21.000000  62.000000  126.000000

# %% [markdown]
# We observe,
#  - Some columns Mean value is lesser than Median value then it indicates the data is positively skewed or right skewed.
#     - Some columns Mean value is greater than Median value then it indicates the data is let skewed.
#      - Observe the high difference between 75% and max it may be indicates outliers.

# %% [markdown]
# # EDA

# %%
sns.set(style='dark',font_scale=1.2)
sns.set(rc={'axes.facecolor':'#ADD8E6','figure.facecolor':'#87CEEB'})
sns.set_context('poster',font_scale = .4)

# %%
figure, axs = plt.subplots(1, 2, figsize=(14, 6))

sns.histplot(x=df['W'], ax=axs[0], bins=30)

sns.histplot(x=df['H'], ax=axs[1], bins=30)

plt.show()

# %% [markdown]
# # Bi-variate Analysis

# %%
figure, axs = plt.subplots(1, 2, figsize=(14, 6))

sns.scatterplot(x=df['W'], y=df['R'], ax=axs[0])
axs[0].set_title('RUN VS WINS')
axs[0].set_xlabel('Wins')
axs[0].set_ylabel('Run')

sns.regplot(x=df['H'], y=df['R'], ax=axs[1])
axs[1].set_title('RUN VS HIT')
axs[1].set_xlabel('Base Hit')
axs[1].set_ylabel('Run')

plt.show()

# %% [markdown]
# We observe that,
#    - It shows the positive upward trends which is suggest that higher Wins are associated with more Runs.
#      - Second graph,It shows a positive slope indicates that more Base Hits are associated with more Runs, suggesting a direct relationship.

# %%
figure, axs = plt.subplots(1, 2, figsize=(14, 6))

sns.scatterplot(y=df['R'], x=df['AB'], hue=df['W'], ax=axs[0])
axs[0].set_title('BAT VS RUN')
axs[0].set_ylabel('Run')
axs[0].set_xlabel('Time at Bat')

sns.scatterplot(x=df['H'], y=df['CG'], ax=axs[1], hue=df['W'])
axs[1].set_title('WIN VS HIT')
axs[1].set_xlabel('Base Hit')
axs[1].set_ylabel('Win')

plt.show()

# %% [markdown]
# We observe that,
#   - It shows a positive slope can indicate whether more Time at Bat is associated with more Runs.
#        - In second graph, it shows points are widely spread out it could suggest that Hit and Win are influenced by multiple factors, or that relationship is not straightforward.

# %%
figure, axs = plt.subplots(1, 2, figsize=(14, 6))

sns.regplot(y=df['RA'], x=df['ER'],  ax=axs[0])
axs[0].set_title('EARNED RUN VS AVERAGE RUN')
axs[0].set_ylabel('Avg. Run')
axs[0].set_xlabel('Earned Run')

sns.scatterplot(x=df['HR'], y=df['SO'], ax=axs[1], hue=df['W'])
axs[1].set_title('STRIKE OUT VS HOME RUNS')
axs[1].set_xlabel('Home Runs')
axs[1].set_ylabel('Strike out')

plt.show()

# %% [markdown]
# We observe that,
#
#   - It shows the positive upward trends which is suggest that if earned run is increased then avg run score also increased.
#      - Here in second graph it shows points are widely spread out it could suggest that Home runs and Strike out rate are influenced by multiple factors, or that relationship is not straightforward.

# %%
figure, axs = plt.subplots(1, 2, figsize=(14, 6))

sns.kdeplot(x=df['RA'],ax=axs[0])
axs[0].set_xlabel('Avg. Run')


sns.kdeplot(x=df['HR'], ax=axs[1])
axs[1].set_xlabel('Home Runs')

plt.show()

# %%
figure, axs = plt.subplots(1, 2, figsize=(14, 6))

sns.regplot(y=df['RA'], x=df['ERA'],  ax=axs[0])
axs[0].set_title('EARNED RUN AVERAGE VS AVERAGE RUN')
axs[0].set_ylabel('Avg. Run')
axs[0].set_xlabel('Earned Run Avg.')

sns.regplot(x=df['2B'], y=df['R'], ax=axs[1])
axs[1].set_title('2B VS SCORED RUNS')
axs[1].set_xlabel('Scored Runs')
axs[1].set_ylabel('2B')

plt.show()

# %% [markdown]
# We observe that,
#   -  it shows a positive slope which is indicates that if average earn run score is increased then average run also increased.
#      - in second graph also show the upward trends which could suggest that more a batter striking the pitched ball and safely reaching second base without being called out by the umpire rate is associated with more runs.

# %%
figure, axs = plt.subplots(1, 2, figsize=(14, 6))

sns.scatterplot(y=df['BB'], x=df['W'],  ax=axs[0])
axs[0].set_title('WALK VS WIN')
axs[0].set_ylabel('Base on balls ')
axs[0].set_xlabel('Win')

sns.regplot(x=df['ER'], y=df['W'], ax=axs[1])
axs[1].set_title('EARNED RUN VS Win')
axs[1].set_xlabel('Earned Run')
axs[1].set_ylabel('Win')

plt.show()

# %% [markdown]
# We observe that,
#   -  Here it shows points are widely spread out it could suggest that number of wins and base on balls rate are influenced by multiple factors, or that relationship is not straightforward.
#     - in second graph it shows a downtrend slope which suggest that it could a negative relationship i.e wins and earnd run are not associated with each other.

# %%
figure, axs = plt.subplots(1, 2, figsize=(14, 6))

sns.scatterplot(y=df['HR'], x=df['R'],  ax=axs[0])
axs[0].set_title('HOME RUNS VS SCORED RUN')
axs[0].set_ylabel('Home Run ')
axs[0].set_xlabel('Run Score')

sns.scatterplot(x=df['AB'], y=df['3B'], ax=axs[1])
axs[1].set_title('TIE AT BAT VS 3B')
axs[1].set_xlabel('Time at Bat')
axs[1].set_ylabel('3b')

plt.show()

# %% [markdown]
# We observe that,
#   - The cluster shows that the team or player that hits the more home runs but not score more runs.
#      - Here in second graph, it shows points are widely spread out it could suggest that 3b and Time at bat are influenced by multiple factors, or that relationship is not straightforward.

# %%
plt.figure(figsize=(15,10))
p=1

for col in df.columns:
    if p < 10:
        ax=plt.subplot(3,3,p)
        sns.distplot(x=df[col])
        plt.title(f'Distribution of {col}')
    p+=1
plt.tight_layout()

# %% [markdown]
# - We observe the distribution plot, it shows that some features are normally distributed and some are skewed.

# %% [markdown]
# # Multivariate Analysis

# %% [markdown]
# # *  Check Correlation using Heat Map

# %%
df_corr = df.corr().abs()
plt.figure(figsize=(20,15))
sns.heatmap(df_corr, annot=True, annot_kws={'size' : 10}, cmap='Blues')
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# We observe that,
#   - the ERA,ER,RA are strongly correlate with target variable that means these 3 feature are more associated with model prediction.
#     - ERA,RA and ER are strongly correlate with each other.But here we cannot remove it bacause of it directly corelate with target variable.

# %% [markdown]
# # * Check Outliers

# %%
plt.figure(figsize=(15, 10))
p=1
for col in df.columns:
    if p < 16 :
        ax = plt.subplot(4,4,p)
        sns.boxplot(df[col])
    p +=1    
    
plt.tight_layout()

# %% [markdown]
# BY observe,
#  - Most of the features don't have any outliers.
#     - Only ERA, SHO AND R column shows some outliers are present.So now we remove the outliers.

# %%
# apply zscore to remove outlier
from scipy.stats import zscore
col = ['ERA','SHO','R']
z_score = zscore(df[col])

abs_z_score = np.abs(z_score)

filtering_entry = np.all(abs_z_score < 3, axis=1)

df1 = df[filtering_entry]

df1.describe()
# Out:
#                 W           R           AB            H          2B  \
# count   29.000000   29.000000    29.000000    29.000000   29.000000
# mean    80.551724  681.241379  5516.517241  1400.896552  273.586207
# std     10.384006   45.357040    71.701076    56.264265   17.269952
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  650.000000  5463.000000  1363.000000  262.000000
# 50%     81.000000  689.000000  5511.000000  1382.000000  274.000000
# 75%     87.000000  713.000000  5571.000000  1420.000000  288.000000
# max    100.000000  764.000000  5649.000000  1515.000000  303.000000
#
#               3B          HR          BB           SO          SB          RA  \
# count  29.000000   29.000000   29.000000    29.000000   29.000000   29.000000
# mean   31.793103  161.275862  465.620690  1251.551724   83.344828  688.862069
# std    10.276114   29.600792   54.728821   103.930123   23.202949   73.300616
# min    13.000000  100.000000  375.000000   973.000000   44.000000  525.000000
# 25%    26.000000  140.000000  426.000000  1159.000000   69.000000  635.000000
# 50%    32.000000  156.000000  471.000000  1264.000000   83.000000  698.000000
# 75%    39.000000  177.000000  496.000000  1312.000000   97.000000  733.000000
# max    49.000000  230.000000  567.000000  1518.000000  134.000000  844.000000
#
#                ER        ERA         CG        SHO         SV           E
# count   29.000000  29.000000  29.000000  29.000000  29.000000   29.000000
# mean   636.758621   3.961724   3.344828  11.344828  43.379310   94.551724
# std     71.195734   0.461148   2.729153   4.185655   7.816712   14.153713
# min    478.000000   2.940000   0.000000   4.000000  28.000000   75.000000
# 25%    584.000000   3.670000   1.000000   9.000000  38.000000   86.000000
# 50%    646.000000   4.030000   3.000000  12.000000  43.000000   92.000000
# 75%    680.000000   4.240000   5.000000  13.000000  47.000000   97.000000
# max    799.000000   5.040000  11.000000  21.000000  62.000000  126.000000

# %%
X = df1.drop(columns=['W'])
y = df1.W

# %% [markdown]
# # Feature Selection

# %%
from sklearn.feature_selection import SelectKBest,mutual_info_regression

select = SelectKBest(score_func=mutual_info_regression, k=10)
x_select = select.fit_transform(X, y)


scores = select.scores_

feature_names = X.columns

feature_scores = pd.DataFrame({
    'Feature': feature_names,
    'Score': scores
})

top_features = feature_scores.nlargest(10, 'Score')

print(top_features)
# Out:
#    Feature     Score
# 9       RA  0.515989
# 10      ER  0.496932
# 11     ERA  0.487217
# 14      SV  0.377769
# 6       BB  0.094292
# 7       SO  0.048964
# 0        R  0.038644
# 13     SHO  0.035442
# 1       AB  0.000000
# 2        H  0.000000

# %%
# Extract the names of the top features
x1 = pd.DataFrame(x_select, columns=top_features['Feature'].values)
x1.head()
# Out:
#       RA     ER     ERA     SV     BB    SO     R   SHO    AB      H
# 0  724.0  383.0   973.0  641.0  601.0  3.73   2.0   8.0  56.0   88.0
# 1  696.0  439.0  1264.0  700.0  653.0  4.07   2.0  12.0  45.0   86.0
# 2  669.0  533.0  1157.0  640.0  584.0  3.67  11.0  10.0  38.0   79.0
# 3  622.0  404.0  1231.0  701.0  643.0  3.98   7.0   9.0  37.0  101.0
# 4  689.0  455.0  1259.0  803.0  746.0  4.64   7.0  12.0  35.0   86.0

# %% [markdown]
# # Feature Scaling using StandardScaler

# %%
from sklearn.preprocessing import StandardScaler

sc = StandardScaler()
x = pd.DataFrame(sc.fit_transform(x1), columns=x1.columns)

# %% [markdown]
# - Here for removing biasness we apply scaling technique.

# %% [markdown]
# # To check Multicolinearity using VIF method

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
f = x.columns
d = {'Feature': f}
d['VIF'] = [variance_inflation_factor(x.values, i) for i in range(len(f))]
df1 = pd.DataFrame(d)

df1
# Out:
#   Feature         VIF
# 0      RA    1.392432
# 1      ER    2.344744
# 2     ERA    1.291749
# 3      SV  123.769364
# 4      BB  414.068858
# 5      SO  261.470442
# 6       R    1.749863
# 7     SHO    2.468767
# 8      AB    2.848688
# 9       H    1.573197

# %%
x.drop('BB', axis=1, inplace=True)

# %%
f = x.columns
d = {'Feature': f}
d['VIF'] = [variance_inflation_factor(x.values, i) for i in range(len(f))]
df1 = pd.DataFrame(d)

df1
# Out:
#   Feature        VIF
# 0      RA   1.197120
# 1      ER   2.272103
# 2     ERA   1.291640
# 3      SV  72.110167
# 4      SO  69.722602
# 5       R   1.743707
# 6     SHO   2.284924
# 7      AB   2.292953
# 8       H   1.545263

# %%
x.drop('SO', axis=1, inplace=True)

# %%
f = x.columns
d = {'Feature': f}
d['VIF'] = [variance_inflation_factor(x.values, i) for i in range(len(f))]
df1 = pd.DataFrame(d)

df1
# Out:
#   Feature       VIF
# 0      RA  1.147341
# 1      ER  1.948862
# 2     ERA  1.228273
# 3      SV  3.332999
# 4       R  1.702602
# 5     SHO  2.250074
# 6      AB  2.279091
# 7       H  1.096481

# %% [markdown]
# - We observe there is no multicolinearity present.

# %% [markdown]
# # Check Skewness

# %%
x.skew()
# Out:
# RA    -0.215364
# ER     0.151193
# ERA   -0.233815
# SV     0.018155
# R      0.854980
# SHO    0.526943
# AB     0.627480
# H      0.840271
# dtype: float64

# %%
x['R'] = np.cbrt(x['R'])

# %%
x['SHO'] = np.cbrt(x['SHO'])

# %%
x['AB'] = np.cbrt(x['AB'])

# %%
x['H'] = np.cbrt(x['H'])

# %%
x.skew()
# Out:
# RA    -0.215364
# ER     0.151193
# ERA   -0.233815
# SV     0.018155
# R      0.367138
# SHO   -0.098558
# AB     0.153150
# H      0.525223
# dtype: float64

# %% [markdown]
# - There are almost remove the skewness.

# %% [markdown]
# # Model Building

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.25, random_state=42)

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error
from sklearn.model_selection import cross_val_score,KFold
from sklearn.ensemble import GradientBoostingRegressor,ExtraTreesRegressor
from sklearn.linear_model import Lasso,Ridge,ElasticNet

# %%
def metric_score(reg, x_train, y_train, x_test, y_test):
    train_accu = r2_score(reg.predict(x_train),y_train)*100
    y_pred = reg.predict(x_test)
    test_accu = r2_score(y_test, y_pred) * 100
    mse = mean_squared_error(y_test, y_pred)
    mae = mean_absolute_error(y_test, y_pred)
    rmse = np.sqrt(mean_squared_error(y_test,y_pred))
    return train_accu, test_accu, mse, mae, rmse

# %%
def cross(reg, x, y):
    k = KFold(n_splits=5)
    score = cross_val_score(reg, x, y, cv=k, scoring='r2')
    print("Cross Validation Score : {}".format(score))
    print("Average Cross Validation Score : {}".format(score.mean()))
    print("\n------------------") 
    difference = (r2_score(y_test,y_pred) - score.mean())*100
    return difference

# %%
models = [
    ('Lasso', Lasso()),
    ('Ridge', Ridge()),
    ('ElasticNet', ElasticNet()),
    ('Random Forest Regressor', RandomForestRegressor()),
    ('Gradient Boosting Regrssor', GradientBoostingRegressor()),
    ('ExtraTrees Regressor', ExtraTreesRegressor())
]

# %%
for name, reg in models:
    reg.fit(x_train, y_train)
    y_pred = reg.predict(x_test)
    
    train_accu, test_accu, mse, mae, rmse = metric_score(reg, x_train, y_train, x_test, y_test)
    
    print(f'{name} Metrics:')
    print('---------------------------------------------------')
    print(f'Train Accuracy: {train_accu:.2f}%')
    print(f'Test Accuracy: {test_accu:.2f}%')
    print('Mean Squared Error:', mse)
    print('Mean Absolute Error:', mae)
    print('Root Mean Squared Error:', rmse)
    
    
    difference = cross(reg, x, y)
    print(f"Difference between test accuracy and average cross-validation score: {difference:.4f}")
    print("*"*50)
# Out:
# Lasso Metrics:
# ---------------------------------------------------
# Train Accuracy: 81.01%
# Test Accuracy: 75.45%
# Mean Squared Error: 26.993968584670014
# Mean Absolute Error: 4.589465638202299
# Root Mean Squared Error: 5.195572017080508
# Cross Validation Score : [ 0.73838482 -0.26193353  0.75761981  0.7280224   0.93457821]
# Average Cross Validation Score : 0.5793343421038032
#
# ------------------
# Difference between test accuracy and average cross-validation score: 17.5126
# **************************************************
# Ridge Metrics:
# ---------------------------------------------------
# Train Accuracy: 90.74%
# Test Accuracy: 85.44%
# Mean Squared Error: 16.007615043015395
# Mean Absolute Error: 3.7290295423309807
# Root Mean Squared Error: 4.000951767144337
# Cross Validation Score : [ 0.618777   -0.62061715  0.73914511  0.96987314  0.91383651]
# Average Cross Validation Score : 0.5242029233586687
#
# ------------------
# Difference between test accuracy and average cross-validation score: 33.0191
# **************************************************
# ElasticNet Metrics:
# ---------------------------------------------------
# Train Accuracy: 62.21%
# Test Accuracy: 63.54%
# Mean Squared Error: 40.08657651933483
# Mean Absolute Error: 5.583681298494856
# Root Mean Squared Error: 6.331396095596517
# Cross Validation Score : [ 0.41663467 -0.08758051  0.58300325  0.47275725  0.8832139 ]
# Average Cross Validation Score : 0.4536057135917339
#
# ------------------
# Difference between test accuracy and average cross-validation score: 18.1764
# **************************************************
# Random Forest Regressor Metrics:
# ---------------------------------------------------
# Train Accuracy: 95.17%
# Test Accuracy: 54.02%
# Mean Squared Error: 50.5536
# Mean Absolute Error: 5.734999999999999
# Root Mean Squared Error: 7.110105484449581
# Cross Validation Score : [ 0.11547045 -5.06577368  0.57084676  0.41265721  0.90476533]
# Average Cross Validation Score : -0.6124067855366518
#
# ------------------
# Difference between test accuracy and average cross-validation score: 115.2567
# **************************************************
# Gradient Boosting Regrssor Metrics:
# ---------------------------------------------------
# Train Accuracy: 100.00%
# Test Accuracy: 46.98%
# Mean Squared Error: 58.290478782121816
# Mean Absolute Error: 6.5736281808228725
# Root Mean Squared Error: 7.634820153881938
# Cross Validation Score : [ 0.04931147 -8.64793311  0.48358024  0.41408287  0.81083953]
# Average Cross Validation Score : -1.3780237993464306
#
# ------------------
# Difference between test accuracy and average cross-validation score: 184.7809
# **************************************************
# ExtraTrees Regressor Metrics:
# ---------------------------------------------------
# Train Accuracy: 100.00%
# Test Accuracy: 44.94%
# Mean Squared Error: 60.5308375
# Mean Absolute Error: 6.971250000000001
# Root Mean Squared Error: 7.780156650093878
# Cross Validation Score : [ 0.3213567  -5.56165658  0.47540301  0.24727951  0.82245814]
# Average Cross Validation Score : -0.7390318436240783
#
# ------------------
# Difference between test accuracy and average cross-validation score: 118.8439
# **************************************************

# %% [markdown]
# - Ridge Regression appears to be the best overall model based on test accuracy (86.28%) and the balance between test performance and cross-validation score. It also has a relatively high average cross-validation score (0.6252) and a lower error compared to other models.
#     - Ridge Regression also performs well in terms of mean squared error (15.08), mean absolute error (3.30), and root mean squared error (3.88), which are lower than those of Random Forest, Gradient Boosting, and ExtraTrees.
#         - The models with higher average cross-validation scores show more stability and better generalization.

# %% [markdown]
# # Tuning the Final Model

# %%
param = {
    'alpha': [0.1, 1, 10]
}

# %%
g_ridge = GridSearchCV(Ridge(), param_grid=param, cv=5, scoring='neg_mean_squared_error')
g_ridge.fit(x_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=Ridge(), param_grid={'alpha': [0.1, 1, 10]},
#              scoring='neg_mean_squared_error')

# %%
g_ridge.best_params_
# Out:
# {'alpha': 1}

# %%
R = Ridge(alpha= 1)
R.fit(x_train,y_train)
R_pred = R.predict(x_test)
print('\n------------------------------------------')
print('Training Accuracy : {}'.format(r2_score(R.predict(x_train),y_train)*100))
print('\n--------------------------------------------')
print('Testing Accuracy : {}'.format(r2_score(y_test,R_pred)*100))
print('\n')
print('Mean Squared Error : ',mean_squared_error(y_test,R_pred))
print('Mean Absolute Error : ',mean_absolute_error(y_test,R_pred))
print('Root Mean Squared Error : ',np.sqrt(mean_squared_error(y_test,R_pred)))
# Out:
# ------------------------------------------
# Training Accuracy : 90.74271588593449
#
# --------------------------------------------
# Testing Accuracy : 85.43934959134472
#
#
# Mean Squared Error :  16.007615043015395
# Mean Absolute Error :  3.7290295423309807
# Root Mean Squared Error :  4.000951767144337

# %% [markdown]
# # Save the model

# %%
import joblib
joblib.dump(R,'Baseball_Win_Prediction.pkl')
# Out:
# ['Baseball_Win_Prediction.pkl']
