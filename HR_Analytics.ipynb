# %% [markdown]
# Problem Statement : Here we have to analyze and predict whether he/she would attrite or not from company.

# %% [markdown]
# The dataset contains information about employees in a company. Here is a description of each column:
#
# Age: The age of the employee (integer).
#
# Attrition: Whether the employee has left the company or not (object).
#
# BusinessTravel: Frequency of business travel (object).
#
# DailyRate: The daily rate of pay for the employee (integer).
#
# Department: Department in which the employee works (object).
#
# DistanceFromHome: Distance from home to work in miles (integer).
#
# Education: Level of education of the employee (integer).
#
# EducationField: Field of education of the employee (object).
#
# EmployeeCount: Number of employees (always 1) (integer).
#
# EmployeeNumber: Unique identifier for each employee (integer).
#
# EnvironmentSatisfaction: Satisfaction level with the work environment (integer).
#
# Gender: Gender of the employee (object).
#
# HourlyRate: Hourly rate of pay for the employee (integer).
#
# JobInvolvement: Level of job involvement (integer).
#
# JobLevel: Level of job within the company (integer).
#
# JobRole: Role of the employee in the company (object).
#
# JobSatisfaction: Satisfaction level with the job (integer).
#
# MaritalStatus: Marital status of the employee (object).
#
# MonthlyIncome: Monthly income of the employee (integer).
#
# MonthlyRate: Monthly rate of pay for the employee (integer).
#
# NumCompaniesWorked: Number of companies the employee has worked for (integer).
#
# Over18: Whether the employee is over 18 years old (object).
#
# OverTime: Whether the employee works overtime or not (object).
#
# PercentSalaryHike: Percentage increase in salary (integer).
#
# PerformanceRating: Performance rating of the employee (integer).
#
# RelationshipSatisfaction: Satisfaction level with work relationships (integer).
#
# StandardHours: Standard number of working hours (always 80) (integer).
#
# StockOptionLevel: Level of stock option (integer).
#
# TotalWorkingYears: Total number of years worked (integer).
#
# TrainingTimesLastYear: Number of training sessions attended last year (integer).
#
# WorkLifeBalance: Level of work-life balance (integer).
#
# YearsAtCompany: Number of years spent at the company (integer).
#
# YearsInCurrentRole: Number of years in the current role (integer).
#
# YearsSinceLastPromotion: Number of years since the last promotion (integer).
#
# YearsWithCurrManager: Number of years with the current manager (integer)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv('WA_Fn-UseC_-HR-Employee-Attrition.csv')

# %%
# Copy the original dataset to another object
df = data.copy()

# %%
df
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
# Show the first five rows of the dataframe
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
# Show the last five rows of the dataframe
df.tail()
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# 1465                23          2        Medical              1
# 1466                 6          1        Medical              1
# 1467                 4          3  Life Sciences              1
# 1468                 2          3        Medical              1
# 1469                 8          3        Medical              1
#
#       EmployeeNumber  ...  RelationshipSatisfaction StandardHours  \
# ...

# %%
df.size
# Out:
# 51450

# %%
def analyzed_data(df):
    #Show the dimension of the dataFrame
    print('The shape of the dataset is :', df.shape)
    print('*'*40, '\n')
    
    #check the datatpes
    type_of_data = df.dtypes
    print('List of DataTypes in Dataset :')
    print('******************************')
    print(type_of_data.to_frame('list of Data Type'))
    print('\n')
    
    # check the missing value of the dataset
    missing_values = df.isnull().sum()
    print('Total Missing Value : ')
    print('**********************')
    print(missing_values.to_frame('Count of Missing Values'))
    print('\n')
    
    #check duplicate values
    duplicated_value = df.duplicated().sum()
    print('Total Duplicate Value')
    print('*********************')
    print(duplicated_value)

# %%
analyzed_data(df)
# Out:
# The shape of the dataset is : (1470, 35)
# ****************************************
#
# List of DataTypes in Dataset :
# ******************************
#                          list of Data Type
# Age                                  int64
# Attrition                           object
# BusinessTravel                      object
# DailyRate                            int64
# Department                          object
# DistanceFromHome                     int64
# Education                            int64
# EducationField                      object
# EmployeeCount                        int64
# EmployeeNumber                       int64
# EnvironmentSatisfaction              int64
# Gender                              object
# HourlyRate                           int64
# JobInvolvement                       int64
# JobLevel                             int64
# JobRole                             object
# JobSatisfaction                      int64
# ...

# %% [markdown]
# - By observe that the dataset has 1470 observations.
# - By observe The dataset is complete with no missing values. This indicates good data quality.
# - By observe that,
#         There are 26 columns with integer data types
#         The remaining columns are all object types, indicating they represent categorical variables.
# - Here we check the total duplicate values and observe that No duplicate records found in the dataset.

# %%
# Show the list of the columns
df.columns.to_list()
# Out:
# ['Age',
#  'Attrition',
#  'BusinessTravel',
#  'DailyRate',
#  'Department',
#  'DistanceFromHome',
#  'Education',
#  'EducationField',
#  'EmployeeCount',
#  'EmployeeNumber',
#  'EnvironmentSatisfaction',
#  'Gender',
#  'HourlyRate',
#  'JobInvolvement',
#  'JobLevel',
#  'JobRole',
#  'JobSatisfaction',
#  'MaritalStatus',
#  'MonthlyIncome',
#  'MonthlyRate',
#  'NumCompaniesWorked',
#  'Over18',
#  'OverTime',
#  'PercentSalaryHike',
#  'PerformanceRating',
#  'RelationshipSatisfaction',
#  'StandardHours',
#  'StockOptionLevel',
#  'TotalWorkingYears',
#  'TrainingTimesLastYear',
#  'WorkLifeBalance',
#  'YearsAtCompany',
#  'YearsInCurrentRole',
#  'YearsSinceLastPromotion',
#  'YearsWithCurrManager']

# %%
#Show the number of unique observations for each column
unique = df.nunique()
print('Total Unique Value Count :')
print('****************************')
unique.to_frame('Total Count')
# Out:
# Total Unique Value Count :
# ****************************
#                           Total Count
# Age                                43
# Attrition                           2
# BusinessTravel                      3
# DailyRate                         886
# Department                          3
# DistanceFromHome                   29
# Education                           5
# EducationField                      6
# EmployeeCount                       1
# EmployeeNumber                   1470
# EnvironmentSatisfaction             4
# Gender                              2
# HourlyRate                         71
# JobInvolvement                      4
# JobLevel                            5
# JobRole                             9
# JobSatisfaction                     4
# MaritalStatus                       3
# MonthlyIncome                    1349
# MonthlyRate                      1427
# NumCompaniesWorked                 10
# Over18                              1
# ...

# %% [markdown]
# - After using df.nunique(), which returns the number of unique values in each column of a DataFrame.
# - Here I observed that our target variable datatype is object and then it converts into numerical datatypes.
# - By primary attention there are 4 columns has no use in this analysis, So drop this columns.

# %%
#Drop the unnecessary column
df.drop(columns=['EmployeeCount','EmployeeNumber','Over18','StandardHours'], axis=1, inplace=True)

# %% [markdown]
# - In this dataframe there all employees are over 18.So we drop the column 'Over18'.
# - EmployeeCount and EmployeeNumber are not required for futher analysis so we drop it.
# - Standard hours of working are also same for all employees so no need it for fither analysis and drop it.

# %%
#Categorical Columns
cat_column = df.select_dtypes(['object']).columns
#Numerical Columns
num_column = df.select_dtypes(['number']).columns


print(cat_column)
print(num_column)
# Out:
# Index(['Attrition', 'BusinessTravel', 'Department', 'EducationField', 'Gender',
#        'JobRole', 'MaritalStatus', 'OverTime'],
#       dtype='object')
# Index(['Age', 'DailyRate', 'DistanceFromHome', 'Education',
#        'EnvironmentSatisfaction', 'HourlyRate', 'JobInvolvement', 'JobLevel',
#        'JobSatisfaction', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'PercentSalaryHike', 'PerformanceRating', 'RelationshipSatisfaction',
#        'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear',
#        'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole',
#        'YearsSinceLastPromotion', 'YearsWithCurrManager'],
#       dtype='object')

# %%
# Show the summary of dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 31 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EnvironmentSatisfaction   1470 non-null   int64
#  9   Gender                    1470 non-null   object
#  10  HourlyRate                1470 non-null   int64
#  11  JobInvolvement            1470 non-null   int64
#  12  JobLevel                  1470 non-null   int64
#  13  JobRole                   1470 non-null   object
# ...

# %%
# Show the statistical summary of numerical data
df.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  \
# count  1470.000000  1470.000000       1470.000000  1470.000000
# mean     36.923810   802.485714          9.192517     2.912925
# std       9.135373   403.509100          8.106864     1.024165
# min      18.000000   102.000000          1.000000     1.000000
# 25%      30.000000   465.000000          2.000000     2.000000
# 50%      36.000000   802.000000          7.000000     3.000000
# 75%      43.000000  1157.000000         14.000000     4.000000
# max      60.000000  1499.000000         29.000000     5.000000
#
#        EnvironmentSatisfaction   HourlyRate  JobInvolvement     JobLevel  \
# count              1470.000000  1470.000000     1470.000000  1470.000000
# mean                  2.721769    65.891156        2.729932     2.063946
# std                   1.093082    20.329428        0.711561     1.106940
# min                   1.000000    30.000000        1.000000     1.000000
# ...

# %% [markdown]
# By observe the statistical summary,
#   - In this the count of all columns are same so there is no missing values is present.
#     - In this dataset the employees average age is 36 and average daily rate is 802 and average monthly income 6502.
#      - the Mean value is greater than Median in some columns that indicates the data is rightly skewed.(Mean > Median)
#         - the Median value is greater than Mean in some columns that indicates the data is leftly skewed.(Mean < Median)
#          - observe the difference of max and 75% value so it may have outliers.

# %%
# Show the statistical summary of  categorical data
df.describe(include='object').T
# Out:
#                count unique                     top  freq
# Attrition       1470      2                      No  1233
# BusinessTravel  1470      3           Travel_Rarely  1043
# Department      1470      3  Research & Development   961
# EducationField  1470      6           Life Sciences   606
# Gender          1470      2                    Male   882
# JobRole         1470      9         Sales Executive   326
# MaritalStatus   1470      3                 Married   673
# OverTime        1470      2                      No  1054

# %%
df.Attrition.value_counts()
# Out:
# No     1233
# Yes     237
# Name: Attrition, dtype: int64

# %% [markdown]
# # Univariate Analysis

# %%
sns.set(style="white",font_scale=1.5)
sns.set(rc={"axes.facecolor":"#FFFAF0","figure.facecolor":"#FFFAF0"})
sns.set_context("poster",font_scale = .4)

# %%
figure, axs = plt.subplots(1, 2, figsize=(14, 6))


sns.countplot(x=df['Attrition'], color='b', ax=axs[0])
axs[0].set_title('Count of Attrition')
axs[0].set_xlabel('Attrition')
axs[0].set_ylabel('Count')


c = df['Attrition'].value_counts()
c.plot.pie(ax=axs[1], autopct='%1.1f%%', explode=(0,0.1), colors=['y', 'r'], shadow=True)
axs[1].set_title('Class Distribution')
axs[1].set_ylabel('')

plt.tight_layout()
plt.show()

# %% [markdown]
# - By observe the count plot it indicates that data is imbalance, So we need to balance the data for avoid the biasness.

# %%
df.MaritalStatus.value_counts()
# Out:
# Married     673
# Single      470
# Divorced    327
# Name: MaritalStatus, dtype: int64

# %%
df.Gender.value_counts()
# Out:
# Male      882
# Female    588
# Name: Gender, dtype: int64

# %%
figure, axs=plt.subplots(1,2, figsize=(14,6))

a = df['Gender'].value_counts()
a.plot.pie(ax = axs[0], autopct = '%1.1f%%', colors=['y','b'], shadow=True)
axs[0].set_title('Gender Distribution')
axs[0].set_ylabel('')

b= df['MaritalStatus'].value_counts()
b.plot.pie(ax=axs[1], autopct='%1.1f%%', shadow=True)
axs[1].set_title('Marital Status')
axs[1].set_ylabel('')

plt.tight_layout()
plt.show()

# %% [markdown]
# - Here we observe 60% male employees and 40% female employees are working in this company.
# - Wheathear 46% are married and 32% are single and 22% are divorced professionals are working in company.

# %%
figure, axs = plt.subplots(1, 2, figsize=(14, 6))


sns.countplot(x=df['BusinessTravel'], color='g', ax=axs[0])
axs[0].set_title('Count of Travel')
axs[0].set_xlabel('Business Travel')
axs[0].set_ylabel('Count')


sns.histplot(ax=axs[1], x=df['Age'], hue=df['Attrition'])
axs[1].set_title('Age Distribution')
axs[1].set_ylabel('Count')

plt.tight_layout()
plt.show()

# %% [markdown]
# By observe,
#    - Here we observe the maximum number of employee travel rarely for company.
#     - Here we observe the age between 25-35 are high chance of attrite from company.

# %%
figure, axs = plt.subplots(1, 2, figsize=(14, 6))

sns.countplot(ax=axs[1], x=df['JobLevel'], hue=df['Attrition'])
axs[1].set_title('Job Level Distribution')

sns.countplot(x=df['EducationField'], ax=axs[0], hue=df['Attrition'])
axs[0].set_title('Distribution of Education field')
plt.xticks(rotation=45)

plt.tight_layout()
plt.show()

# %% [markdown]
# By observe,
#  - the employee whose education background is life science has high attrition possibility as compared to others field.
#     - the employee who are belongs job level 1 has high chances to leave from company.

# %%
figure, axs = plt.subplots(1, 2, figsize=(14, 6))


sns.countplot(x=df['JobSatisfaction'], ax=axs[0], hue=df['Attrition'])
plt.xticks(rotation=45)

sns.countplot(ax=axs[1], x=df['Department'], hue=df['Attrition'])

plt.tight_layout()
plt.show()

# %% [markdown]
# By observe,
#  - Here the employee who work in R&D department has high chances to left the company.

# %%
plt.figure(figsize=(14,6))
sns.countplot(x=df['JobRole'], hue=df['Attrition'])
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# By observe,
#  - Here the employee who work as a Sales Executive and Laboratory Technician has high posibility to leave this company.

# %% [markdown]
# # Bi-Variate Analysis

# %%
figure, axs = plt.subplots(1, 2, figsize=(14, 6))

sns.countplot(x=df['Department'], hue=df['Attrition'], color='b', ax=axs[0])
plt.xticks(rotation=45)

sns.barplot(x=df['Department'], y=df['DailyRate'], ax=axs[1], hue=df['Gender'], color='lightgreen')
plt.xticks(rotation=45)

plt.tight_layout()
plt.show()

# %% [markdown]
# By observe,
#  - Here we can say that, the HR department has pay high amount on daily basis for female employee as compared to male.
#     - Here we can say that, the Research & Development department has pay high amount on daily basis for male employee.
#      - Here we see that, the Research & Development department has high attrition rate.

# %%
figure, axs = plt.subplots(1, 2, figsize=(14, 6))

sns.barplot(x=df['Department'], y=df['MonthlyIncome'], hue=df['Gender'], ax=axs[0], color='yellow')

sns.barplot(x=df['BusinessTravel'], y=df['MonthlyIncome'], hue=df['Gender'], ax=axs[1], color='g')
plt.xticks(rotation=45)

plt.tight_layout()
plt.show()

# %% [markdown]
# By observe,
#  - the employees who are travel rarely have high monthly income compared to others.
#      - the female employess who are working at HR department have high income.

# %%
sns.catplot(x=df['Attrition'], col=df['MaritalStatus'], kind='count', color='r')
plt.show()

# %% [markdown]
# - Here we observe,the employees whose marital status are single has high attrition rate.

# %%
sns.catplot(x=df['Attrition'], col=df['Gender'], kind='count', color='lightgreen')
plt.show()

# %% [markdown]
# - Here we observe the male employees attrition rate is high compared to female employees.

# %%
sns.catplot(x=df['OverTime'], col=df['Gender'], kind='count', color='blue')
plt.show()

# %% [markdown]
# - Here we observe the male employees over time is high compared to female employees.

# %%
sns.catplot(x=df['PerformanceRating'], col=df['Gender'], kind='count', color='skyblue')
plt.show()

# %% [markdown]
# - Here we observe the male employees have high performance rating compared to female employees.

# %%
a =sns.catplot(x=df['EducationField'], col=df['Gender'], kind='count', color='skyblue')
a.set_xticklabels(rotation=45)
plt.show()

# %% [markdown]
# - Here we observe that the male employees with life science background has high count in the company.

# %%
plt.figure(figsize=(14,6))
sns.regplot(x=df['MonthlyIncome'], y=df['JobLevel'])
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# - Here we see the linear relationship and upward trends.Wheather the monthly income is increases then job level also increases.

# %%
figure, axs = plt.subplots(1, 2, figsize=(14, 6))

sns.pointplot(x=df['MaritalStatus'], y=df['MonthlyIncome'], hue=df['Attrition'], ax=axs[0], color='skyblue')

sns.pointplot(x=df['BusinessTravel'], y=df['MonthlyIncome'], hue=df['Attrition'], ax=axs[1], color='g')
plt.xticks(rotation=45)

plt.tight_layout()
plt.show()

# %%
df['EnvironmentSatisfaction'].value_counts()
# Out:
# 3    453
# 4    446
# 2    287
# 1    284
# Name: EnvironmentSatisfaction, dtype: int64

# %%
plt.figure(figsize=(14,6))
sns.countplot(x=df['EnvironmentSatisfaction'], hue=df['Attrition'],color='skyblue')
plt.xticks(ticks=[0, 1, 2, 3], labels=['Low', 'Medium', 'High', 'Very High'], rotation=45)
plt.show()

# %% [markdown]
# - Here we observe that the employee with low environment satisfaction rate has high chances to leave the company.it indicates if company provide good environment to employee then it can retain the employee.

# %%
df['StockOptionLevel'].value_counts()
# Out:
# 0    631
# 1    596
# 2    158
# 3     85
# Name: StockOptionLevel, dtype: int64

# %%
plt.figure(figsize=(14,6))
sns.countplot(x=df['StockOptionLevel'], hue=df['Attrition'],color='lightgreen')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# - We observe that the employee with higher stock options has lower attrition rate.It indicates if company gives stock option to employee then that helps to retain employee.

# %% [markdown]
# # Multivariate Analysis

# %%
plt.figure(figsize=(15,10))
p=1

for col in df.select_dtypes(include=['int64']).columns:
    if p <= 9:
        ax=plt.subplot(3,3,p)
        sns.distplot(x=df[col])
        plt.title(f'Distribution of {col}')
    p+=1
plt.tight_layout()

# %% [markdown]
# # Correlation Analysis

# %%
df_cor = df.corr().abs()
plt.figure(figsize=(20,15))
sns.heatmap(df_cor, annot=True, annot_kws={'size': 10})
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# We observe that,
#   - 'Job Level' and 'Monthly Income' columns are highly correlate with 'Total Working Years'.
#     - 'Performance Rating' and 'Percent Salary Hike' are highly correlated.
#      - 'Years at Company' are highly correlated with 'Years with current manager' and 'Years in current role columns'.

# %% [markdown]
# # Check Outliers

# %%
plt.figure(figsize=(15, 10))
p=1
for col in df.select_dtypes(include=['int64']).columns:
    if p < 16 :
        ax = plt.subplot(4,4,p)
        sns.boxplot(df[col])
    p +=1    
    
plt.tight_layout()

# %% [markdown]
# We observe from box plot,
#  - Most of the features don't have any outliers.
#     - Only 'MonthlyIncome' column shows some outliers are present.So now we remove the outliers.
#      - In the dataset rest of features variable are categorical data, so no need to check the outliers.

# %%
from scipy.stats import zscore

# Calculate z-score for the 'MonthlyIncome' column
z_score = zscore(df['MonthlyIncome'])
# Calculate absolute z-scores
abs_z_score = np.abs(z_score)

filtering_entry = (abs_z_score < 3)

df = df[filtering_entry]

df.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  \
# count  1470.000000  1470.000000       1470.000000  1470.000000
# mean     36.923810   802.485714          9.192517     2.912925
# std       9.135373   403.509100          8.106864     1.024165
# min      18.000000   102.000000          1.000000     1.000000
# 25%      30.000000   465.000000          2.000000     2.000000
# 50%      36.000000   802.000000          7.000000     3.000000
# 75%      43.000000  1157.000000         14.000000     4.000000
# max      60.000000  1499.000000         29.000000     5.000000
#
#        EnvironmentSatisfaction   HourlyRate  JobInvolvement     JobLevel  \
# count              1470.000000  1470.000000     1470.000000  1470.000000
# mean                  2.721769    65.891156        2.729932     2.063946
# std                   1.093082    20.329428        0.711561     1.106940
# min                   1.000000    30.000000        1.000000     1.000000
# ...

# %% [markdown]
# # Encode the Categorical data

# %%
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()
for i in df.columns:
    if df[i].dtypes == 'object':
        df[i] = encoder.fit_transform(df[i].values.reshape(-1,1))
df.head()
# Out:
#    Age  Attrition  BusinessTravel  DailyRate  Department  DistanceFromHome  \
# 0   41          1               2       1102           2                 1
# 1   49          0               1        279           1                 8
# 2   37          1               2       1373           1                 2
# 3   33          0               1       1392           1                 3
# 4   27          0               2        591           1                 2
#
#    Education  EducationField  EnvironmentSatisfaction  Gender  ...  \
# 0          2               1                        2       0  ...
# 1          1               1                        3       1  ...
# 2          2               4                        4       1  ...
# 3          4               1                        4       0  ...
# 4          1               3                        1       1  ...
#
#    PerformanceRating  RelationshipSatisfaction  StockOptionLevel  \
# ...

# %%
X = df.drop(columns=['Attrition'])
y = df['Attrition']

# %% [markdown]
# # Feature Selection

# %%
from sklearn.feature_selection import SelectKBest,f_classif

select = SelectKBest(score_func=f_classif, k=15)
x_select = select.fit_transform(X, y)


scores = select.scores_

feature_names = X.columns

feature_scores = pd.DataFrame({
    'Feature': feature_names,
    'Score': scores
})

top_features = feature_scores.nlargest(15, 'Score')

print(top_features)
# Out:
#                     Feature      Score
# 18                 OverTime  94.656457
# 23        TotalWorkingYears  44.252491
# 11                 JobLevel  43.215344
# 14            MaritalStatus  39.599763
# 27       YearsInCurrentRole  38.838303
# 15            MonthlyIncome  38.488819
# 0                       Age  38.175887
# 29     YearsWithCurrManager  36.712311
# 22         StockOptionLevel  28.140501
# 26           YearsAtCompany  27.001624
# 10           JobInvolvement  25.241985
# 13          JobSatisfaction  15.890004
# 7   EnvironmentSatisfaction  15.855209
# 4          DistanceFromHome   8.968277
# 12                  JobRole   6.649672

# %%
# Extract the names of the top features
x1 = pd.DataFrame(x_select, columns=top_features['Feature'].values)
x1.head()
# Out:
#    OverTime  TotalWorkingYears  JobLevel  MaritalStatus  YearsInCurrentRole  \
# 0        41                  1         2              3                   2
# 1        49                  8         3              2                   2
# 2        37                  2         4              2                   1
# 3        33                  3         4              3                   1
# 4        27                  2         1              3                   1
#
#    MonthlyIncome  Age  YearsWithCurrManager  StockOptionLevel  YearsAtCompany  \
# 0              7    4                     2              5993               1
# 1              6    2                     1              5130               0
# 2              2    3                     2              2090               1
# 3              6    3                     1              2909               1
# 4              2    2                     1              3468               0
#
# ...

# %% [markdown]
# # Check Imbalance

# %%
y.value_counts()
# Out:
# 0    1233
# 1     237
# Name: Attrition, dtype: int64

# %% [markdown]
# - Here we observe the data is imbalanced.So need to balance the dataset using resampling method.

# %%
# balance the dataset
from imblearn.over_sampling import SMOTE
SM = SMOTE()
x2, y1 = SM.fit_resample(x1,y)

# %% [markdown]
# # To check Multicolinearity using VIF method

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
f = x2.columns
d = {'Feature': f}
d['VIF'] = [variance_inflation_factor(x2.values, i) for i in range(len(f))]
df1 = pd.DataFrame(d)

df1
# Out:
#                     Feature        VIF
# 0                  OverTime  22.149006
# 1         TotalWorkingYears   2.511632
# 2                  JobLevel   6.289469
# 3             MaritalStatus  10.967529
# 4        YearsInCurrentRole  44.342894
# 5             MonthlyIncome   4.515764
# 6                       Age   6.182141
# 7      YearsWithCurrManager   4.812058
# 8          StockOptionLevel  29.352039
# 9            YearsAtCompany   1.442905
# 10           JobInvolvement   2.350580
# 11          JobSatisfaction  12.785565
# 12  EnvironmentSatisfaction   9.441674
# 13         DistanceFromHome   6.667628
# 14                  JobRole   6.444789

# %%
x2.drop('YearsInCurrentRole', axis=1, inplace=True)

# %%
f = x2.columns
d = {'Feature': f}
d['VIF'] = [variance_inflation_factor(x2.values, i) for i in range(len(f))]
df1 = pd.DataFrame(d)

df1
# Out:
#                     Feature        VIF
# 0                  OverTime  21.776831
# 1         TotalWorkingYears   2.469240
# 2                  JobLevel   6.266730
# 3             MaritalStatus  10.917328
# 4             MonthlyIncome   4.465381
# 5                       Age   6.121716
# 6      YearsWithCurrManager   4.786158
# 7          StockOptionLevel   7.560803
# 8            YearsAtCompany   1.437946
# 9            JobInvolvement   2.342689
# 10          JobSatisfaction  12.693642
# 11  EnvironmentSatisfaction   9.440845
# 12         DistanceFromHome   6.667299
# 13                  JobRole   6.420781

# %% [markdown]
# - Here we observe the 'OverTime' column has high VIF value among others.But this column is very important for model performance.So, we keep as it is.

# %%
x2.drop('JobSatisfaction', axis=1, inplace=True)

# %%
f = x2.columns
d = {'Feature': f}
d['VIF'] = [variance_inflation_factor(x2.values, i) for i in range(len(f))]
df1 = pd.DataFrame(d)

df1
# Out:
#                     Feature        VIF
# 0                  OverTime  16.139532
# 1         TotalWorkingYears   2.460042
# 2                  JobLevel   6.228380
# 3             MaritalStatus  10.797052
# 4             MonthlyIncome   4.340837
# 5                       Age   6.062551
# 6      YearsWithCurrManager   4.730403
# 7          StockOptionLevel   5.088934
# 8            YearsAtCompany   1.437932
# 9            JobInvolvement   2.334209
# 10  EnvironmentSatisfaction   8.577607
# 11         DistanceFromHome   6.666909
# 12                  JobRole   6.416348

# %% [markdown]
# - Now we see that most of the features VIF score is below 10.then it suggest that there is no multicolinearity present.

# %% [markdown]
# # Check Skewness

# %%
x2.skew()
# Out:
# OverTime                   0.519348
# TotalWorkingYears          0.827491
# JobLevel                   0.000300
# MaritalStatus             -0.329349
# MonthlyIncome             -0.273426
# Age                        0.016861
# YearsWithCurrManager      -0.125006
# StockOptionLevel           1.606908
# YearsAtCompany             0.872981
# JobInvolvement             1.343062
# EnvironmentSatisfaction    1.987782
# DistanceFromHome           1.152616
# JobRole                    1.016008
# dtype: float64

# %% [markdown]
# - We need to remove skewness

# %%
x2['TotalWorkingYears'] = np.sqrt(x2['TotalWorkingYears'])

# %%
x2['StockOptionLevel'] = np.cbrt(x2['StockOptionLevel'])

# %%
x2['YearsAtCompany'] = np.sqrt(x2['YearsAtCompany'])

# %%
x2['JobInvolvement'] = np.cbrt(x2['JobInvolvement'])

# %%
x2['EnvironmentSatisfaction'] = np.cbrt(x2['EnvironmentSatisfaction'])

# %%
x2['DistanceFromHome'] = np.sqrt(x2['DistanceFromHome'])

# %%
x2['JobRole'] = np.sqrt(x2['JobRole'])

# %%
x2.skew()
# Out:
# OverTime                   0.519348
# TotalWorkingYears          0.248608
# JobLevel                   0.000300
# MaritalStatus             -0.329349
# MonthlyIncome             -0.273426
# Age                        0.016861
# YearsWithCurrManager      -0.125006
# StockOptionLevel           0.423612
# YearsAtCompany             0.872981
# JobInvolvement             0.422680
# EnvironmentSatisfaction   -0.423432
# DistanceFromHome          -0.054347
# JobRole                   -0.065649
# dtype: float64

# %% [markdown]
# - Now almost There is no skewness present

# %% [markdown]
# # Feature Scaling

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
x3 = pd.DataFrame(scaler.fit_transform(x2), columns=x2.columns)

# %% [markdown]
# # Find best Random State

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import accuracy_score,confusion_matrix,roc_curve,roc_auc_score,classification_report

# %%
x_train,x_test,y_train,y_test = train_test_split(x3,y1,test_size= 0.30)

# %%
param = {
     'random_state': range(0, 100)
}

g = GridSearchCV(RandomForestClassifier(), param, cv=5, scoring='accuracy')
g.fit(x_train,y_train)

print('Best random state : ',g.best_params_['random_state'])
# Out:
# Best random state :  21

# %% [markdown]
# # Model Building

# %%
# again train in train_test_split
x_train,x_test,y_train,y_test = train_test_split(x3,y1,test_size= 0.30, random_state=21)

# %%
from sklearn.ensemble import GradientBoostingClassifier,ExtraTreesClassifier,AdaBoostClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import cross_val_score,KFold

# %%
def metrics_score(clf, x_train, y_train, x_test, y_test):
    train_accu= accuracy_score(clf.predict(x_train),y_train)*100
    test_accu= accuracy_score(y_test,clf.predict(x_test))*100
    cm = confusion_matrix(y_test,clf.predict(x_test))
    c_report = classification_report(y_test,clf.predict(x_test))
    return train_accu,test_accu,cm,c_report

# %%
def cross_val(model, x_train, y_train):
    k = KFold(n_splits=5)
    score = cross_val_score(model, x_train, y_train, cv=k)
    print("Cross Validation Score : {}".format(score))
    print("Average Cross Validation Score : {}".format(score.mean()))
    print("\n------------------")
    difference = accuracy_score(y_test, clf.predict(x_test)) - score.mean()
    return difference

# %%
models = [
    ('Logistic Regression', LogisticRegression()),
    ('Random Forest Classifier', RandomForestClassifier()),
    ('Gradient Boosting Classifier', GradientBoostingClassifier()),
    ('Extra Trees Classifier', ExtraTreesClassifier()),
    ('Decision Tree Classifier', DecisionTreeClassifier()),
    ('AdaBoost Classifier', AdaBoostClassifier()),
    ('K-Nearest Neighbors Classifier', KNeighborsClassifier())
]

# %% [markdown]
# # Model Evaluation

# %%
for name, clf in models:
    clf.fit(x_train, y_train)
    y_pred = clf.predict(x_test)
    
    train_accu, test_accu, cm, c_report = metrics_score(clf, x_train, y_train, x_test, y_test)
    
    print(f"{name} Metrics:")
    print('---------------------------------------------------')
    print(f"Train Accuracy: {train_accu:.2f}%")
    print(f"Test Accuracy: {test_accu:.2f}%")
    print("Confusion Matrix:\n", cm)
    print("Classification Report:\n", c_report)
    
    difference = cross_val(clf, x_train, y_train)
    print(f"Difference between test accuracy and average cross-validation score: {difference:.4f}")
    print("="*50)
# Out:
# Logistic Regression Metrics:
# ---------------------------------------------------
# Train Accuracy: 81.34%
# Test Accuracy: 80.81%
# Confusion Matrix:
#  [[301  67]
#  [ 75 297]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.80      0.82      0.81       368
#            1       0.82      0.80      0.81       372
#
#     accuracy                           0.81       740
#    macro avg       0.81      0.81      0.81       740
# weighted avg       0.81      0.81      0.81       740
#
# Cross Validation Score : [0.80924855 0.76811594 0.82608696 0.80869565 0.84347826]
# Average Cross Validation Score : 0.8111250733014996
#
# ------------------
# Difference between test accuracy and average cross-validation score: -0.0030
# ...
# Random Forest Classifier Metrics:
# ---------------------------------------------------
# Train Accuracy: 100.00%
# Test Accuracy: 90.14%
# Confusion Matrix:
#  [[332  36]
#  [ 37 335]]
# ...

# %% [markdown]
# # From the observations we can conclude that "Random Forest Classification" is our best fit and best performing model and it has a high average cross-validation score,It has a higher test accuracy from other models as well as low difference between test accuracy and cross validation.

# %% [markdown]
# # Model Tuning

# %%
param = {
    'n_estimators' : [200,100,150],
    'criterion' : ['gini', 'entropy', 'log_loss'],
    'min_samples_split' : [2,3,1],
    'min_samples_leaf' : [3,2,1,],
    'max_features' : ['sqrt', 'log2']
}

# %%
rfcv = GridSearchCV(RandomForestClassifier(), param_grid=param, cv=5, scoring='accuracy')
rfcv.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestClassifier(),
#              param_grid={'criterion': ['gini', 'entropy', 'log_loss'],
#                          'max_features': ['sqrt', 'log2'],
#                          'min_samples_leaf': [3, 2, 1],
#                          'min_samples_split': [2, 3, 1],
#                          'n_estimators': [200, 100, 150]},
#              scoring='accuracy')

# %%
rfcv.best_params_
# Out:
# {'criterion': 'gini',
#  'max_features': 'sqrt',
#  'min_samples_leaf': 1,
#  'min_samples_split': 3,
#  'n_estimators': 100}

# %%
final_model = RandomForestClassifier(criterion= 'gini', max_features= 'sqrt', min_samples_leaf= 1, min_samples_split= 3, n_estimators= 100)
final_model.fit(x_train,y_train)
pred = final_model.predict(x_test)
print('Testing Accuracy : {:.2f} %'.format(round(accuracy_score(y_test, pred) * 100, 2)))
print('-----------------------------------------------')
print(confusion_matrix(y_test,pred))
print('\n')
print(classification_report(y_test,pred))
# Out:
# Testing Accuracy : 89.59 %
# -----------------------------------------------
# [[331  37]
#  [ 40 332]]
#
#
#               precision    recall  f1-score   support
#
#            0       0.89      0.90      0.90       368
#            1       0.90      0.89      0.90       372
#
#     accuracy                           0.90       740
#    macro avg       0.90      0.90      0.90       740
# weighted avg       0.90      0.90      0.90       740

# %% [markdown]
# - Our Final Model's Accuracy is approx 90%.

# %% [markdown]
# # Save the Model

# %%
import joblib
joblib.dump(final_model,'HR_Analytics.pkl')
# Out:
# ['HR_Analytics.pkl']
