# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="white",font_scale=1.0)
sns.set(rc={"axes.facecolor":"#FFFAF0","figure.facecolor":"#FFFAF0"})
sns.set_context("poster",font_scale = .4)

import warnings
warnings.filterwarnings('ignore')

# %%
tempareture = pd.read_csv('https://raw.githubusercontent.com/dsrscientist/Dataset2/main/temperature.csv')

# %%
# Copy the original dataset to another object
df = tempareture.copy()

# %%
# Show the first five rows of the dataframe
df.head()
# Out:
#    station        Date  Present_Tmax  Present_Tmin  LDAPS_RHmin  LDAPS_RHmax  \
# 0      1.0  30-06-2013          28.7          21.4    58.255688    91.116364
# 1      2.0  30-06-2013          31.9          21.6    52.263397    90.604721
# 2      3.0  30-06-2013          31.6          23.3    48.690479    83.973587
# 3      4.0  30-06-2013          32.0          23.4    58.239788    96.483688
# 4      5.0  30-06-2013          31.4          21.9    56.174095    90.155128
#
#    LDAPS_Tmax_lapse  LDAPS_Tmin_lapse  LDAPS_WS    LDAPS_LH  ...  LDAPS_PPT2  \
# 0         28.074101         23.006936  6.818887   69.451805  ...         0.0
# 1         29.850689         24.035009  5.691890   51.937448  ...         0.0
# 2         30.091292         24.565633  6.138224   20.573050  ...         0.0
# 3         29.704629         23.326177  5.650050   65.727144  ...         0.0
# 4         29.113934         23.486480  5.735004  107.965535  ...         0.0
#
# ...

# %%
# Show the last five rows of the dataframe
df.tail()
# Out:
#       station        Date  Present_Tmax  Present_Tmin  LDAPS_RHmin  \
# 7747     23.0  30-08-2017          23.3          17.1    26.741310
# 7748     24.0  30-08-2017          23.3          17.7    24.040634
# 7749     25.0  30-08-2017          23.2          17.4    22.933014
# 7750      NaN         NaN          20.0          11.3    19.794666
# 7751      NaN         NaN          37.6          29.9    98.524734
#
#       LDAPS_RHmax  LDAPS_Tmax_lapse  LDAPS_Tmin_lapse   LDAPS_WS    LDAPS_LH  \
# 7747    78.869858         26.352081         18.775678   6.148918   72.058294
# 7748    77.294975         27.010193         18.733519   6.542819   47.241457
# 7749    77.243744         27.939516         18.522965   7.289264    9.090034
# 7750    58.936283         17.624954         14.272646   2.882580  -13.603212
# 7751   100.000153         38.542255         29.619342  21.857621  213.414006
#
#       ...  LDAPS_PPT2  LDAPS_PPT3  LDAPS_PPT4      lat      lon       DEM  \
# ...

# %%
# Show the dimension of the dataframe
print('The Shape of the Dataset is : ',df.shape)
# Out:
# The Shape of the Dataset is :  (7752, 25)

# %% [markdown]
# **- In the dataset there are only have 7752 rows and 25 columns.**

# %%
# Show the data types of the dataframe
print('The datatypes are : \n' + '*'*20)
print(df.dtypes)
# Out:
# The datatypes are :
# ********************
# station             float64
# Date                 object
# Present_Tmax        float64
# Present_Tmin        float64
# LDAPS_RHmin         float64
# LDAPS_RHmax         float64
# LDAPS_Tmax_lapse    float64
# LDAPS_Tmin_lapse    float64
# LDAPS_WS            float64
# LDAPS_LH            float64
# LDAPS_CC1           float64
# LDAPS_CC2           float64
# LDAPS_CC3           float64
# LDAPS_CC4           float64
# LDAPS_PPT1          float64
# LDAPS_PPT2          float64
# LDAPS_PPT3          float64
# LDAPS_PPT4          float64
# lat                 float64
# lon                 float64
# DEM                 float64
# Slope               float64
# Solar radiation     float64
# Next_Tmax           float64
# Next_Tmin           float64
# dtype: object

# %%
# Show the columns
df.columns.to_list()
# Out:
# ['station',
#  'Date',
#  'Present_Tmax',
#  'Present_Tmin',
#  'LDAPS_RHmin',
#  'LDAPS_RHmax',
#  'LDAPS_Tmax_lapse',
#  'LDAPS_Tmin_lapse',
#  'LDAPS_WS',
#  'LDAPS_LH',
#  'LDAPS_CC1',
#  'LDAPS_CC2',
#  'LDAPS_CC3',
#  'LDAPS_CC4',
#  'LDAPS_PPT1',
#  'LDAPS_PPT2',
#  'LDAPS_PPT3',
#  'LDAPS_PPT4',
#  'lat',
#  'lon',
#  'DEM',
#  'Slope',
#  'Solar radiation',
#  'Next_Tmax',
#  'Next_Tmin']

# %%
# To check the missing value
print('Total Missing Values are : \n' + '*'*25)
print(df.isnull().sum())
# Out:
# Total Missing Values are :
# *************************
# station              2
# Date                 2
# Present_Tmax        70
# Present_Tmin        70
# LDAPS_RHmin         75
# LDAPS_RHmax         75
# LDAPS_Tmax_lapse    75
# LDAPS_Tmin_lapse    75
# LDAPS_WS            75
# LDAPS_LH            75
# LDAPS_CC1           75
# LDAPS_CC2           75
# LDAPS_CC3           75
# LDAPS_CC4           75
# LDAPS_PPT1          75
# LDAPS_PPT2          75
# LDAPS_PPT3          75
# LDAPS_PPT4          75
# lat                  0
# lon                  0
# DEM                  0
# Slope                0
# Solar radiation      0
# Next_Tmax           27
# Next_Tmin           27
# dtype: int64

# %% [markdown]
# **- Based on the observations, there are some missing values in our dataset. We will handle these missing values due to the small percentage of data that is missing relative to the total observations.we'll just fill them instead of drop.**

# %%
# Handling the missing value from dataset
df.fillna(df.mean(), inplace=True)

# %%
# again check the missing value after removing null data
print('Total Missing Values are : \n' + '*'*25)
print(df.isnull().sum())
# Out:
# Total Missing Values are :
# *************************
# station             0
# Date                2
# Present_Tmax        0
# Present_Tmin        0
# LDAPS_RHmin         0
# LDAPS_RHmax         0
# LDAPS_Tmax_lapse    0
# LDAPS_Tmin_lapse    0
# LDAPS_WS            0
# LDAPS_LH            0
# LDAPS_CC1           0
# LDAPS_CC2           0
# LDAPS_CC3           0
# LDAPS_CC4           0
# LDAPS_PPT1          0
# LDAPS_PPT2          0
# LDAPS_PPT3          0
# LDAPS_PPT4          0
# lat                 0
# lon                 0
# DEM                 0
# Slope               0
# Solar radiation     0
# Next_Tmax           0
# Next_Tmin           0
# dtype: int64

# %% [markdown]
# **- By observation we found some missing value in Date column.**

# %%
# drop the rows with missing value for date
df.dropna(subset=['Date'], inplace=True)

# %%
# again check the missing value after removing null data
print('Total Missing Values are : \n' + '*'*25)
print(df.isnull().sum())
# Out:
# Total Missing Values are :
# *************************
# station             0
# Date                0
# Present_Tmax        0
# Present_Tmin        0
# LDAPS_RHmin         0
# LDAPS_RHmax         0
# LDAPS_Tmax_lapse    0
# LDAPS_Tmin_lapse    0
# LDAPS_WS            0
# LDAPS_LH            0
# LDAPS_CC1           0
# LDAPS_CC2           0
# LDAPS_CC3           0
# LDAPS_CC4           0
# LDAPS_PPT1          0
# LDAPS_PPT2          0
# LDAPS_PPT3          0
# LDAPS_PPT4          0
# lat                 0
# lon                 0
# DEM                 0
# Slope               0
# Solar radiation     0
# Next_Tmax           0
# Next_Tmin           0
# dtype: int64

# %% [markdown]
# **- Now there is no missing value present.**

# %%
df.shape
# Out:
# (7750, 25)

# %%
# To check the duplicate value
print('Total Duplicate Values are : \n' + '*'*27)
print(df.duplicated().sum())
# Out:
# Total Duplicate Values are :
# ***************************
# 0

# %% [markdown]
# **- Based on our observations, there are no duplicated values in our dataset.**

# %%
# To check the unique value
print('The Unique Values are : \n' + '*'*25)
df.nunique().to_frame('No. of unique value')
# Out:
# The Unique Values are :
# *************************
#                   No. of unique value
# station                            25
# Date                              310
# Present_Tmax                      168
# Present_Tmin                      156
# LDAPS_RHmin                      7673
# LDAPS_RHmax                      7665
# LDAPS_Tmax_lapse                 7676
# LDAPS_Tmin_lapse                 7676
# LDAPS_WS                         7676
# LDAPS_LH                         7676
# LDAPS_CC1                        7570
# LDAPS_CC2                        7583
# LDAPS_CC3                        7600
# LDAPS_CC4                        7525
# LDAPS_PPT1                       2813
# LDAPS_PPT2                       2511
# LDAPS_PPT3                       2357
# LDAPS_PPT4                       1919
# lat                                12
# lon                                25
# DEM                                25
# Slope                              25
# ...

# %% [markdown]
# **- Since the 'station' variable is unique and not associated with the model building or predictions, we have decided to drop this unnecessary feature.**

# %%
# drop station named feature
df.drop(columns=['station','LDAPS_PPT1','LDAPS_PPT2','LDAPS_PPT3','LDAPS_PPT4'], axis=1, inplace=True)

# %%
# Show the summary of dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7750 entries, 0 to 7749
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Date              7750 non-null   object
#  1   Present_Tmax      7750 non-null   float64
#  2   Present_Tmin      7750 non-null   float64
#  3   LDAPS_RHmin       7750 non-null   float64
#  4   LDAPS_RHmax       7750 non-null   float64
#  5   LDAPS_Tmax_lapse  7750 non-null   float64
#  6   LDAPS_Tmin_lapse  7750 non-null   float64
#  7   LDAPS_WS          7750 non-null   float64
#  8   LDAPS_LH          7750 non-null   float64
#  9   LDAPS_CC1         7750 non-null   float64
#  10  LDAPS_CC2         7750 non-null   float64
#  11  LDAPS_CC3         7750 non-null   float64
#  12  LDAPS_CC4         7750 non-null   float64
#  13  lat               7750 non-null   float64
#  14  lon               7750 non-null   float64
#  15  DEM               7750 non-null   float64
# ...

# %%
# Change the date format
df['Date'] = pd.to_datetime(df['Date'])

# %%
# Set the Date column as an index
df.set_index('Date', inplace=True)

# %%
df.head()
# Out:
#             Present_Tmax  Present_Tmin  LDAPS_RHmin  LDAPS_RHmax  \
# Date
# 2013-06-30          28.7          21.4    58.255688    91.116364
# 2013-06-30          31.9          21.6    52.263397    90.604721
# 2013-06-30          31.6          23.3    48.690479    83.973587
# 2013-06-30          32.0          23.4    58.239788    96.483688
# 2013-06-30          31.4          21.9    56.174095    90.155128
#
#             LDAPS_Tmax_lapse  LDAPS_Tmin_lapse  LDAPS_WS    LDAPS_LH  \
# Date
# 2013-06-30         28.074101         23.006936  6.818887   69.451805
# 2013-06-30         29.850689         24.035009  5.691890   51.937448
# 2013-06-30         30.091292         24.565633  6.138224   20.573050
# 2013-06-30         29.704629         23.326177  5.650050   65.727144
# 2013-06-30         29.113934         23.486480  5.735004  107.965535
#
#             LDAPS_CC1  LDAPS_CC2  LDAPS_CC3  LDAPS_CC4      lat      lon  \
# Date
# ...

# %%
# Show the statistical summary of data
df.describe()
# Out:
#        Present_Tmax  Present_Tmin  LDAPS_RHmin  LDAPS_RHmax  LDAPS_Tmax_lapse  \
# count   7750.000000   7750.000000  7750.000000  7750.000000       7750.000000
# mean      29.768461     23.225736    56.758753    88.377102         29.613841
# std        2.953516      2.398327    14.585101     7.149011          2.928357
# min       20.000000     11.300000    19.794666    58.936283         17.624954
# 25%       27.800000     21.700000    46.048225    84.318649         27.693733
# 50%       29.900000     23.400000    55.313244    89.699505         29.662273
# 75%       32.000000     24.875000    67.032715    93.703491         31.682567
# max       37.600000     29.900000    98.524734   100.000153         38.542255
#
#        LDAPS_Tmin_lapse     LDAPS_WS     LDAPS_LH    LDAPS_CC1    LDAPS_CC2  \
# count       7750.000000  7750.000000  7750.000000  7750.000000  7750.000000
# mean          23.512993     7.096514    62.495367     0.368744     0.356047
# ...

# %% [markdown]
# **Upon observation:**
#
# **- The counts of all columns are the same, indicating that there are no missing values.**
#
#    **- In some columns, such as Present_Tmax, Present_Tmin, and LDAPS_RHmin, the mean value is less than the median value, suggesting that the data is negatively skewed (left-skewed).**
#
#    **- In other columns, like LDAPS_WS and LDAPS_LH, the mean value is greater than the median, indicating that the data is positively skewed.**
#
#    **- A review suggests the presence of some outliers, based on the differences between the 75th percentile and the maximum value.**

# %% [markdown]
# # EDA

# %%
plt.figure(figsize=(12, 6))
sns.lineplot(df["Next_Tmax"],label="Next_Tmax")
sns.lineplot(df["Next_Tmin"],label="Next_Tmin")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.lineplot(df["Present_Tmax"],label="Present_Tmax")
sns.lineplot(df["Present_Tmin"],label="Present_Tmin")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(15,10))
p=1

for col in df.columns:
    if p < 10:
        ax=plt.subplot(3,3,p)
        sns.histplot(x=df[col])
        plt.title(f'Distribution of {col}')
    p+=1
plt.tight_layout()

# %%
plt.figure(figsize=(15,10))
p=1

for col in df.columns:
    if p < 10:
        ax=plt.subplot(3,3,p)
        sns.distplot(x=df[col])
        plt.title(f'Distribution of {col}')
    p+=1
plt.tight_layout()

# %% [markdown]
# **- By the distribution plot, we see that there some of features are not normally distributed.**

# %% [markdown]
# # Correlation Analysis

# %%
df_corr = df.corr().abs()
plt.figure(figsize=(20,15))
sns.heatmap(df_corr, annot=True, annot_kws={'size' : 10}, cmap='Blues')
plt.title('Correlation Matrix')
plt.show()

# %%
sns.clustermap(df_corr)
plt.show()

# %% [markdown]
# # Check Outlier

# %%
plt.figure(figsize=(15, 10))
p=1
for col in df.columns:
    if p < 16 :
        ax = plt.subplot(4,4,p)
        sns.boxplot(df[col])
    p +=1    
    
plt.tight_layout()

# %% [markdown]
# **- The box plot reveals that some columns contain outliers. To ensure model stability and performance, we need to remove these outliers or unnecessary data from the dataset. Therefore, we will use the z-score method to eliminate them.**

# %%
from scipy import stats


# Calculate Z-scores
z_scores = np.abs(stats.zscore(df))

# Identify outliers
outlier_mask = (z_scores > 3).any(axis=1)

# Remove outliers
x = df[~outlier_mask]


# Check the number of rows after removing outliers
print("Number of rows after removing outliers:", x.shape[0])
# Out:
# Number of rows after removing outliers: 7468

# %%
print('Old Dtaframe size : ',df.shape[0])
print('New Dtaframe size : ',x.shape[0])
# Out:
# Old Dtaframe size :  7750
# New Dtaframe size :  7468

# %%
print('Data Loss Percentage : ',((df.shape[0]-x.shape[0])/df.shape[0])*100)
# Out:
# Data Loss Percentage :  3.638709677419355

# %% [markdown]
# # Remove skewness

# %%
x.skew()
# Out:
# Present_Tmax       -0.224052
# Present_Tmin       -0.208861
# LDAPS_RHmin         0.280498
# LDAPS_RHmax        -0.751954
# LDAPS_Tmax_lapse   -0.093617
# LDAPS_Tmin_lapse   -0.362663
# LDAPS_WS            1.019942
# LDAPS_LH            0.597787
# LDAPS_CC1           0.481928
# LDAPS_CC2           0.468592
# LDAPS_CC3           0.636829
# LDAPS_CC4           0.672361
# lat                 0.106321
# lon                -0.286156
# DEM                 1.778212
# Slope               1.602414
# Solar radiation    -0.502651
# Next_Tmax          -0.262754
# Next_Tmin          -0.214948
# dtype: float64

# %%
x['LDAPS_RHmax'] = np.square(x['LDAPS_RHmax'])

# %%
x['LDAPS_WS'] = np.log(x['LDAPS_WS'])

# %%
x['LDAPS_LH'] = np.cbrt(x['LDAPS_LH'])

# %%
x['LDAPS_CC3'] = np.cbrt(x['LDAPS_CC3'])

# %%
x['LDAPS_CC4'] = np.cbrt(x['LDAPS_CC4'])

# %%
x['DEM'] = np.sqrt(x['DEM'])

# %%
x['Slope'] = np.sqrt(x['Slope'])

# %%
x.skew()
# Out:
# Present_Tmax       -0.224052
# Present_Tmin       -0.208861
# LDAPS_RHmin         0.280498
# LDAPS_RHmax        -0.578107
# LDAPS_Tmax_lapse   -0.093617
# LDAPS_Tmin_lapse   -0.362663
# LDAPS_WS            0.336841
# LDAPS_LH           -0.315368
# LDAPS_CC1           0.481928
# LDAPS_CC2           0.468592
# LDAPS_CC3          -0.577605
# LDAPS_CC4          -0.462970
# lat                 0.106321
# lon                -0.286156
# DEM                 0.522438
# Slope               0.491935
# Solar radiation    -0.502651
# Next_Tmax          -0.262754
# Next_Tmin          -0.214948
# dtype: float64

# %% [markdown]
# **- Based on observation, there is no skewness present now.**

# %%
X = x.drop(columns=['Next_Tmax','Next_Tmin'])
y1 = x['Next_Tmax']
y2 = x['Next_Tmin']

# %% [markdown]
# # For Next Day Maximum Temp.(Next_Tmax )

# %% [markdown]
# # Feature Importance

# %%
from sklearn.ensemble import RandomForestRegressor

rf = RandomForestRegressor(n_estimators=100)
rf.fit(X, y1)

# Get feature importances
importances = rf.feature_importances_

feature_importance_df = pd.DataFrame({
    'Feature': X.columns,
    'Importance': importances
}).sort_values(by='Importance', ascending=False)

# Select the top 12 features
top_features = feature_importance_df.head(12)

print(top_features)
# Out:
#              Feature  Importance
# 4   LDAPS_Tmax_lapse    0.652612
# 0       Present_Tmax    0.063012
# 8          LDAPS_CC1    0.043321
# 10         LDAPS_CC3    0.033554
# 11         LDAPS_CC4    0.029994
# 16   Solar radiation    0.028076
# 6           LDAPS_WS    0.024163
# 9          LDAPS_CC2    0.019758
# 1       Present_Tmin    0.019724
# 5   LDAPS_Tmin_lapse    0.019626
# 2        LDAPS_RHmin    0.015793
# 7           LDAPS_LH    0.015315

# %%
# Extract the names of the top features
x = pd.DataFrame(X, columns=top_features['Feature'].values)
x.head(3)
# Out:
#             LDAPS_Tmax_lapse  Present_Tmax  LDAPS_CC1  LDAPS_CC3  LDAPS_CC4  \
# Date
# 2013-06-30         28.074101          28.7   0.233947   0.544796   0.507783
# 2013-06-30         29.850689          31.9   0.225508   0.542254   0.503610
# 2013-06-30         30.091292          31.6   0.209344   0.588764   0.521864
#
#             Solar radiation  LDAPS_WS  LDAPS_CC2  Present_Tmin  \
# Date
# 2013-06-30      5992.895996  1.919696   0.203896          21.4
# 2013-06-30      5869.312500  1.739042   0.251771          21.6
# 2013-06-30      5863.555664  1.814535   0.257469          23.3
#
#             LDAPS_Tmin_lapse  LDAPS_RHmin  LDAPS_LH
# Date
# 2013-06-30         23.006936    58.255688  4.110499
# 2013-06-30         24.035009    52.263397  3.731014
# 2013-06-30         24.565633    48.690479  2.740099

# %% [markdown]
# # Feature Scaling

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
x1 = pd.DataFrame(scaler.fit_transform(x), columns=x.columns)

# %% [markdown]
# # To check Multicolinearity using VIF method

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
f = x1.columns
d = {'Feature': f}
d['VIF'] = [variance_inflation_factor(x1.values, i) for i in range(len(f))]
df1 = pd.DataFrame(d)

df1
# Out:
#              Feature       VIF
# 0   LDAPS_Tmax_lapse  6.425079
# 1       Present_Tmax  2.554846
# 2          LDAPS_CC1  3.049308
# 3          LDAPS_CC3  3.684377
# 4          LDAPS_CC4  2.497283
# 5    Solar radiation  1.215610
# 6           LDAPS_WS  1.131565
# 7          LDAPS_CC2  4.698488
# 8       Present_Tmin  2.777021
# 9   LDAPS_Tmin_lapse  5.898668
# 10       LDAPS_RHmin  4.831761
# 11          LDAPS_LH  1.305238

# %% [markdown]
# **- Upon reviewing the VIF values, all values were found to be less than 10, indicating that there is no multicollinearity present.**

# %% [markdown]
# # Model Building (next day maximum temp.)

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor,GradientBoostingRegressor,ExtraTreesRegressor,AdaBoostRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import GridSearchCV,cross_val_score,KFold
from sklearn.metrics import r2_score,mean_squared_error,mean_absolute_error

# %%
x_train, x_test, y_train, y_test = train_test_split(x1, y1, test_size=0.30, random_state=42)

# %%
def metric(reg, x_train, x_test, y_train, y_test):
    train_accu = r2_score(reg.predict(x_train),y_train)*100
    y_pred = reg.predict(x_test)
    test_accu = r2_score(y_test, y_pred) * 100
    mse = mean_squared_error(y_test, y_pred)
    mae = mean_absolute_error(y_test, y_pred)
    rmse = np.sqrt(mean_squared_error(y_test,y_pred))
    return train_accu, test_accu, mse, mae, rmse

# %%
def cross(reg, x_train, y_train):
    k = KFold(n_splits=5)
    score = cross_val_score(reg, x_train, y_train, cv=k, scoring='r2')
    print("Cross Validation Score : {}".format(score))
    print("Average Cross Validation Score : {}".format(score.mean()))
    print("\n------------------") 
    difference = (r2_score(y_test,y_pred) - score.mean())
    return difference

# %%
models = [
    ('AdaBoost Regressor', AdaBoostRegressor()),
    ('DecisionTree Regressor', DecisionTreeRegressor()),
    ('Random Forest Regressor', RandomForestRegressor()),
    ('Gradient Boosting Regressor', GradientBoostingRegressor()),
    ('ExtraTrees Regressor', ExtraTreesRegressor()),
    ('KNearest Regressor', KNeighborsRegressor())
]

# %% [markdown]
# # Model Evaluation

# %%
for name, reg in models:
    reg.fit(x_train, y_train)
    y_pred = reg.predict(x_test)
    
    train_accu, test_accu, mse, mae, rmse = metric(reg, x_train, x_test, y_train, y_test)
    
    print(f'{name} Metrics:')
    print('---------------------------------------------------')
    print(f'Train Accuracy: {train_accu:.2f}%')
    print(f'Test Accuracy: {test_accu:.2f}%')
    print('Mean Squared Error:', mse)
    print('Mean Absolute Error:', mae)
    print('Root Mean Squared Error:', rmse)
    
    difference = cross(reg, x_train, y_train)
    print(f"Difference between test accuracy and average cross-validation score: {difference:.4f}")
    print("="*50)
# Out:
# AdaBoost Regressor Metrics:
# ---------------------------------------------------
# Train Accuracy: 60.79%
# Test Accuracy: 73.46%
# Mean Squared Error: 2.359449670853876
# Mean Absolute Error: 1.228114356441882
# Root Mean Squared Error: 1.5360500222498863
# Cross Validation Score : [0.72817956 0.75015198 0.76637952 0.72451416 0.72439425]
# Average Cross Validation Score : 0.7387238936814553
#
# ------------------
# Difference between test accuracy and average cross-validation score: -0.0041
# ...
# DecisionTree Regressor Metrics:
# ---------------------------------------------------
# Train Accuracy: 100.00%
# Test Accuracy: 74.29%
# Mean Squared Error: 2.285445894245656
# Mean Absolute Error: 1.0883197948211398
# Root Mean Squared Error: 1.5117691272961147
# Cross Validation Score : [0.73664394 0.72723857 0.72502436 0.68596672 0.72900759]
# Average Cross Validation Score : 0.7207762341084019
#
# ------------------
# ...

# %% [markdown]
# ***By evaluation,***
#
#    **- From the model evaluation, we observe that two algorithms, Random Forest and ExtraTrees Regressor, perform well and provide precise results but when we compare both models the ExtraTrees Regressor stands out as the best model for our dataset.**
#
#
#
# - Here are the reasons why:
#
#    **-  Higher Average Cross-Validation Score(0.8925) and Test Accuracy(90.38%) and Least difference between test accuracy and average cross-validation(0.0112) in ExtraTrees Regressor from other model.This indicates that ExtraTrees Regressor generally performs well across different subsets of data.**
#
#    **-  ExtraTrees Regressor has a difference of 0.0112, which is better than other models, indicating it generalizes well and is less likely to be overfitting.**
#
#    **-  ExtraTrees Regressor also has least average error rate as compared to other models.**

# %% [markdown]
# # Model Tuning

# %%
params = {
    'n_estimators' : [120,100],
    'criterion' : ['squared_error', 'absolute_error', 'friedman_mse', 'poisson'],
    'min_samples_split' : [2,1],
    'min_samples_leaf' : [2,1],
    'max_features' : ['sqrt', 'log2']
}

# %%
mt = GridSearchCV(ExtraTreesRegressor(), param_grid=params, cv=5, scoring='r2')
mt.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=ExtraTreesRegressor(),
#              param_grid={'criterion': ['squared_error', 'absolute_error',
#                                        'friedman_mse', 'poisson'],
#                          'max_features': ['sqrt', 'log2'],
#                          'min_samples_leaf': [2, 1],
#                          'min_samples_split': [2, 1],
#                          'n_estimators': [120, 100]},
#              scoring='r2')

# %%
mt.best_params_
# Out:
# {'criterion': 'friedman_mse',
#  'max_features': 'sqrt',
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'n_estimators': 120}

# %%
mt_final = ExtraTreesRegressor(criterion= 'friedman_mse', max_features= 'sqrt', min_samples_leaf= 1, min_samples_split= 2, n_estimators= 120)
mt_final.fit(x_train,y_train)
prediction = mt_final.predict(x_test)
print('Testing Accuracy : {:.2f} %'.format(round(r2_score(y_test, prediction) * 100, 2)))
print('-----------------------------------------------')
print('Mean Squared Error:',mean_squared_error(y_test,prediction))
print('Mean Absolute Error:', mean_absolute_error(y_test,prediction))
print('Root Mean Squared Error:', np.sqrt(mean_squared_error(y_test,prediction)))
# Out:
# Testing Accuracy : 90.60 %
# -----------------------------------------------
# Mean Squared Error: 0.835268405356042
# Mean Absolute Error: 0.6905832167216147
# Root Mean Squared Error: 0.9139301972011002

# %% [markdown]
# **- After tuning the final model, the error rate decreased and the accuracy increased to approximately 91%.**

# %% [markdown]
# # For Next Day Minimum Temp.(Next_Tmin )

# %% [markdown]
# # Feature Importance

# %%
from sklearn.ensemble import RandomForestRegressor

rf = RandomForestRegressor(n_estimators=100)
rf.fit(X, y2)

# Get feature importances
importances = rf.feature_importances_

feature_importance_df = pd.DataFrame({
    'Feature': X.columns,
    'Importance': importances
}).sort_values(by='Importance', ascending=False)

# Select the top 13 features
top_features = feature_importance_df.head(13)

print(top_features)
# Out:
#              Feature  Importance
# 5   LDAPS_Tmin_lapse    0.755117
# 1       Present_Tmin    0.063866
# 0       Present_Tmax    0.017715
# 16   Solar radiation    0.016698
# 6           LDAPS_WS    0.015427
# 8          LDAPS_CC1    0.014966
# 11         LDAPS_CC4    0.014003
# 10         LDAPS_CC3    0.013854
# 9          LDAPS_CC2    0.013699
# 2        LDAPS_RHmin    0.011152
# 14               DEM    0.010950
# 3        LDAPS_RHmax    0.009722
# 12               lat    0.009526

# %%
# Extract the names of the top features
x_min = pd.DataFrame(X, columns=top_features['Feature'].values)
x_min.head(3)
# Out:
#             LDAPS_Tmin_lapse  Present_Tmin  Present_Tmax  Solar radiation  \
# Date
# 2013-06-30         23.006936          21.4          28.7      5992.895996
# 2013-06-30         24.035009          21.6          31.9      5869.312500
# 2013-06-30         24.565633          23.3          31.6      5863.555664
#
#             LDAPS_WS  LDAPS_CC1  LDAPS_CC4  LDAPS_CC3  LDAPS_CC2  LDAPS_RHmin  \
# Date
# 2013-06-30  1.919696   0.233947   0.507783   0.544796   0.203896    58.255688
# 2013-06-30  1.739042   0.225508   0.503610   0.542254   0.251771    52.263397
# 2013-06-30  1.814535   0.209344   0.521864   0.588764   0.257469    48.690479
#
#                  DEM  LDAPS_RHmax      lat
# Date
# 2013-06-30  1.397780  8302.191703  37.6046
# 2013-06-30  1.268183  8209.215480  37.6046
# 2013-06-30  1.244968  7051.563320  37.5776

# %% [markdown]
# # Feature Scaling

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
x2 = pd.DataFrame(scaler.fit_transform(x_min), columns=x_min.columns)

# %% [markdown]
# # To check multicolinearity using VIF score

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
f = x2.columns
d = {'Feature': f}
d['VIF'] = [variance_inflation_factor(x2.values, i) for i in range(len(f))]
df2 = pd.DataFrame(d)

df2
# Out:
#              Feature       VIF
# 0   LDAPS_Tmin_lapse  2.746437
# 1       Present_Tmin  2.899552
# 2       Present_Tmax  2.382218
# 3    Solar radiation  1.142474
# 4           LDAPS_WS  1.157418
# 5          LDAPS_CC1  3.084870
# 6          LDAPS_CC4  2.532232
# 7          LDAPS_CC3  3.762974
# 8          LDAPS_CC2  4.315127
# 9        LDAPS_RHmin  3.758613
# 10               DEM  1.143151
# 11       LDAPS_RHmax  2.065263
# 12               lat  1.067631

# %% [markdown]
# **- Upon reviewing the VIF values, all values were found to be less than 10, indicating that there is no multicollinearity present.**

# %% [markdown]
# # Model Buliding

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor,GradientBoostingRegressor,ExtraTreesRegressor,AdaBoostRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import GridSearchCV,cross_val_score,KFold
from sklearn.metrics import r2_score,mean_squared_error,mean_absolute_error

# %%
x_train_min, x_test_min, y_train_min, y_test_min = train_test_split(x2, y2, test_size=0.30, random_state=42)

# %%
def analyze(re, x_train_min, x_test_min, y_train_min, y_test_min):
    train_accu = r2_score(re.predict(x_train_min),y_train_min)*100
    y_pred = re.predict(x_test_min)
    test_accu = r2_score(y_test_min, y_pred) * 100
    mse = mean_squared_error(y_test_min, y_pred)
    mae = mean_absolute_error(y_test_min, y_pred)
    rmse = np.sqrt(mean_squared_error(y_test_min,y_pred))
    return train_accu, test_accu, mse, mae, rmse

# %%
def cross_validation(re, x_train_min, y_train_min):
    k = KFold(n_splits=5)
    score = cross_val_score(re, x_train_min, y_train_min, cv=k, scoring='r2')
    print("Cross Validation Score : {}".format(score))
    print("Average Cross Validation Score : {}".format(score.mean()))
    print("\n------------------") 
    difference = (r2_score(y_test_min,y_pred) - score.mean())
    return difference

# %%
models = [
    ('AdaBoost Regressor', AdaBoostRegressor()),
    ('DecisionTree Regressor', DecisionTreeRegressor()),
    ('Random Forest Regressor', RandomForestRegressor()),
    ('Gradient Boosting Regressor', GradientBoostingRegressor()),
    ('ExtraTrees Regressor', ExtraTreesRegressor()),
    ('KNearest Regressor', KNeighborsRegressor())
]

# %% [markdown]
# # Model Evaluation

# %%
for name, re in models:
    re.fit(x_train_min, y_train_min)
    y_pred = re.predict(x_test_min)
    
    train_accu, test_accu, mse, mae, rmse = analyze(re, x_train_min, x_test_min, y_train_min, y_test_min)
    
    print(f'{name} Metrics:')
    print('---------------------------------------------------')
    print(f'Train Accuracy: {train_accu:.2f}%')
    print(f'Test Accuracy: {test_accu:.2f}%')
    print('Mean Squared Error:', mse)
    print('Mean Absolute Error:', mae)
    print('Root Mean Squared Error:', rmse)
    
    difference = cross_validation(re, x_train_min, y_train_min)
    print(f"Difference between test accuracy and average cross-validation score: {difference:.4f}")
    print("-"*50)
# Out:
# AdaBoost Regressor Metrics:
# ---------------------------------------------------
# Train Accuracy: 68.66%
# Test Accuracy: 79.17%
# Mean Squared Error: 1.1053900744266643
# Mean Absolute Error: 0.8455197319795483
# Root Mean Squared Error: 1.0513753251939406
# Cross Validation Score : [0.76915631 0.78974309 0.77372166 0.76345685 0.77972722]
# Average Cross Validation Score : 0.7751610268395426
#
# ------------------
# Difference between test accuracy and average cross-validation score: 0.0165
# --------------------------------------------------
# DecisionTree Regressor Metrics:
# ---------------------------------------------------
# Train Accuracy: 100.00%
# Test Accuracy: 75.62%
# Mean Squared Error: 1.2936524413977413
# Mean Absolute Error: 0.8244965016484493
# Root Mean Squared Error: 1.1373884303076682
# Cross Validation Score : [0.7047135  0.76357519 0.74689333 0.7579755  0.7145541 ]
# Average Cross Validation Score : 0.7375423238388776
#
# ------------------
# ...

# %% [markdown]
# **By evaluation,**
#
#
#    **- From the model evaluation, we observe that two algorithms, Random Forest and ExtraTrees Regressor, perform well and provide precise results but when we compare both models the ExtraTrees Regressor stands out as the best model for our dataset.**
#
#
#
# **** Here are the reasons why:***
#
#    **-  Higher Average Cross-Validation Score(0.8870) and Test Accuracy(90.00%) and Least difference between test accuracy and average cross-validation(0.01) in ExtraTrees Regressor from other model.This indicates that ExtraTrees Regressor generally performs well across different subsets of data.**
#
#
#    **-  ExtraTrees Regressor has a difference of 0.01, which is better than other models, indicating it generalizes well and is less likely to be overfitting.**
#
#
#    **-  ExtraTrees Regressor also has least average error rate as compared to other models.**

# %% [markdown]
# # Model Tuning

# %%
para = {
    'n_estimators' : [120,100,150],
    'criterion' : ['squared_error', 'absolute_error', 'friedman_mse', 'poisson'],
    'min_samples_split' : [2,1,3],
    'min_samples_leaf' : [2,1,3],
    'max_features' : ['sqrt', 'log2']
}

# %%
mt_min = GridSearchCV(ExtraTreesRegressor(), param_grid=params, cv=5, scoring='r2')
mt_min.fit(x_train_min,y_train_min)
# Out:
# GridSearchCV(cv=5, estimator=ExtraTreesRegressor(),
#              param_grid={'criterion': ['squared_error', 'absolute_error',
#                                        'friedman_mse', 'poisson'],
#                          'max_features': ['sqrt', 'log2'],
#                          'min_samples_leaf': [2, 1],
#                          'min_samples_split': [2, 1],
#                          'n_estimators': [120, 100]},
#              scoring='r2')

# %%
mt_min.best_params_
# Out:
# {'criterion': 'squared_error',
#  'max_features': 'sqrt',
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'n_estimators': 100}

# %%
mt_min_final = ExtraTreesRegressor(criterion= 'squared_error', max_features= 'sqrt', min_samples_leaf= 1, min_samples_split= 2, n_estimators= 100)
mt_min_final.fit(x_train_min,y_train_min)
pred_min = mt_min_final.predict(x_test_min)
print('Testing Accuracy : {:.2f} %'.format(round(r2_score(y_test_min, pred_min) * 100, 2)))
print('-----------------------------------------------')
print('Mean Squared Error:',mean_squared_error(y_test_min,pred_min))
print('Mean Absolute Error:', mean_absolute_error(y_test_min,pred_min))
print('Root Mean Squared Error:', np.sqrt(mean_squared_error(y_test_min,pred_min)))
# Out:
# Testing Accuracy : 90.83 %
# -----------------------------------------------
# Mean Squared Error: 0.48668498662454485
# Mean Absolute Error: 0.5306967191888738
# Root Mean Squared Error: 0.6976281148466889

# %% [markdown]
# **- After tuning the final model, the error rate decreased and the accuracy increased to approximately 91%.**

# %% [markdown]
# # Save the model

# %%
import joblib
joblib.dump(mt_final,'Temperature_Forecast.pkl')
# Out:
# ['Temperature_Forecast.pkl']

# %%
import joblib
joblib.dump(mt_min_final,'Temperature_Forecast.pkl')
# Out:
# ['Temperature_Forecast.pkl']
