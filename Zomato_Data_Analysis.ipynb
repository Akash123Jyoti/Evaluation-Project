# %% [markdown]
# **PROBLEM STATEMENT :**
#
# In this dataset predict 2 things –
# - 1) Average Cost for two
# - 2) Price range

# %% [markdown]
# - Restaurant Id: Unique id of every restaurant across various cities of the world
# - Restaurant Name: Name of the restaurant
# - Country Code: Country in which restaurant is located
# - City: City in which restaurant is located
# - Address: Address of the restaurant
# - Locality: Location in the city
# - Locality Verbose: Detailed description of the locality
# - Longitude: Longitude coordinate of the restaurant
# - Latitude: Latitude coordinate of the restaurant
# - Cuisines: Cuisines offered by the restaurant
# - Average Cost for two: Cost for two people in different currencies
# - Currency: Currency of the country
# - Has Table booking: yes/no
# - Has Online delivery: yes/ no
# - Is delivering: yes/ no
# - Switch to order menu: yes/no
# - Price range: range of price of food
# - Aggregate Rating: Average rating out of 5
# - Rating color: depending upon the average rating color
# - Rating text: text on the basis of rating of rating
# - Votes: Number of ratings casted by people

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="darkgrid",font_scale=1.0)
sns.set(rc={"axes.facecolor":"#ADD8E6","figure.facecolor":"#ADD8E6"})
sns.set_context("poster",font_scale = .4)

import warnings
warnings.filterwarnings('ignore')

# %%
# Load the csv file
zomato = pd.read_csv('zomato.csv', encoding='ISO-8859-1')

# %%
# Load another dataset in excel file
country = pd.read_excel('Country-Code.xlsx')

# %%
# now merge the two dataframes into one
original = pd.merge(zomato, country, on='Country Code')

# %%
# Copy the original dataset to another object
df = original.copy()

# %%
# Show the first five rows of the dataframe
df.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
# Show the last five rows of the dataframe
df.tail()
# Out:
#       Restaurant ID           Restaurant Name  Country Code       City  \
# 9546        5915730              NamlÛ± Gurme           208  ÛÁstanbul
# 9547        5908749             Ceviz AÛôacÛ±           208  ÛÁstanbul
# 9548        5915807                     Huqqa           208  ÛÁstanbul
# 9549        5916112              Aôôk Kahve           208  ÛÁstanbul
# 9550        5927402  Walter's Coffee Roastery           208  ÛÁstanbul
#
#                                                 Address     Locality  \
# 9546  Kemankeô Karamustafa Paôa Mahallesi, RÛ±htÛ±...     Karakí_y
# 9547  Koôuyolu Mahallesi, Muhittin íìstí_ndaÛô Cadd...    Koôuyolu
# 9548  Kuruí_eôme Mahallesi, Muallim Naci Caddesi, N...  Kuruí_eôme
# 9549  Kuruí_eôme Mahallesi, Muallim Naci Caddesi, N...  Kuruí_eôme
# 9550  CafeaÛôa Mahallesi, BademaltÛ± Sokak, No 21/B,...         Moda
#
#             Locality Verbose  Longitude   Latitude  \
# 9546     Karakí_y, ÛÁstanbul  28.977392  41.022793
# ...

# %%
# Show the dimension of the dataframe
print('The Shape of the Dataset is : ',df.shape)
# Out:
# The Shape of the Dataset is :  (9551, 22)

# %%
# Show the columns
df.columns.to_list()
# Out:
# ['Restaurant ID',
#  'Restaurant Name',
#  'Country Code',
#  'City',
#  'Address',
#  'Locality',
#  'Locality Verbose',
#  'Longitude',
#  'Latitude',
#  'Cuisines',
#  'Average Cost for two',
#  'Currency',
#  'Has Table booking',
#  'Has Online delivery',
#  'Is delivering now',
#  'Switch to order menu',
#  'Price range',
#  'Aggregate rating',
#  'Rating color',
#  'Rating text',
#  'Votes',
#  'Country']

# %%
# Show the data types of the dataframe
print('The datatypes are : \n' + '*'*30)
print(df.dtypes)
# Out:
# The datatypes are :
# ******************************
# Restaurant ID             int64
# Restaurant Name          object
# Country Code              int64
# City                     object
# Address                  object
# Locality                 object
# Locality Verbose         object
# Longitude               float64
# Latitude                float64
# Cuisines                 object
# Average Cost for two      int64
# Currency                 object
# Has Table booking        object
# Has Online delivery      object
# Is delivering now        object
# Switch to order menu     object
# Price range               int64
# Aggregate rating        float64
# Rating color             object
# Rating text              object
# Votes                     int64
# Country                  object
# dtype: object

# %%
# To check the missing value
print('Total Missing Values are : \n' + '*'*25)
print(df.isnull().sum())
# Out:
# Total Missing Values are :
# *************************
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# Country                 0
# dtype: int64

# %% [markdown]
# **- By observation, there are only one feature contain missing value.So we need to handle it for clear dataset.**

# %%
# handling the missing value
df['Cuisines'] = df['Cuisines'].fillna(df['Cuisines'].mode()[0])

# %%
# Again to check the missing value
print('Total Missing Values are : \n' + '*'*25)
print(df.isnull().sum())
# Out:
# Total Missing Values are :
# *************************
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                0
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# Country                 0
# dtype: int64

# %% [markdown]
# **- By observation, now there are no missing value present after handling it.**

# %%
# To check the duplicate value
print('Total Duplicate Values are : \n' + '*'*27)
print(df.duplicated().sum())
# Out:
# Total Duplicate Values are :
# ***************************
# 0

# %% [markdown]
# **- By observation, there are no duplicate value present.**

# %%
# To check the unique value
print('The Unique Values are : \n' + '*'*25)
df.nunique().to_frame('No. of unique value')
# Out:
# The Unique Values are :
# *************************
#                       No. of unique value
# Restaurant ID                        9551
# Restaurant Name                      7446
# Country Code                           15
# City                                  141
# Address                              8918
# Locality                             1208
# Locality Verbose                     1265
# Longitude                            8120
# Latitude                             8677
# Cuisines                             1825
# Average Cost for two                  140
# Currency                               12
# Has Table booking                       2
# Has Online delivery                     2
# Is delivering now                       2
# Switch to order menu                    1
# Price range                             4
# Aggregate rating                       33
# Rating color                            6
# Rating text                             6
# ...

# %%
# drop some un-necessary column
df.drop(columns=['Restaurant ID','Restaurant Name','Longitude','Latitude','Country Code'], axis=1, inplace=True)

# %%
# Show the summary of dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9551 entries, 0 to 9550
# Data columns (total 17 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   City                  9551 non-null   object
#  1   Address               9551 non-null   object
#  2   Locality              9551 non-null   object
#  3   Locality Verbose      9551 non-null   object
#  4   Cuisines              9551 non-null   object
#  5   Average Cost for two  9551 non-null   int64
#  6   Currency              9551 non-null   object
#  7   Has Table booking     9551 non-null   object
#  8   Has Online delivery   9551 non-null   object
#  9   Is delivering now     9551 non-null   object
#  10  Switch to order menu  9551 non-null   object
#  11  Price range           9551 non-null   int64
#  12  Aggregate rating      9551 non-null   float64
#  13  Rating color          9551 non-null   object
#  14  Rating text           9551 non-null   object
# ...

# %%
# check value for categorical col
for i in df.select_dtypes(include=['object']).columns:
     print(f'The value count of {i}:\n{df[i].value_counts()}\n')
# Out:
# The value count of City:
# New Delhi       5473
# Gurgaon         1118
# Noida           1080
# Faridabad        251
# Ghaziabad         25
#                 ...
# Huskisson          1
# Panchkula          1
# Forrest            1
# Flaxton            1
# Chatham-Kent       1
# Name: City, Length: 141, dtype: int64
#
# The value count of Address:
# Sector 41, Noida                                                                         11
# Dilli Haat, INA, New Delhi                                                               11
# Greater Kailash (GK) 1, New Delhi                                                        10
# The Imperial, Janpath, New Delhi                                                          9
# Palate of Delhi, Dhaula Kuan Metro Station, Chanakyapuri, New Delhi                       8
#                                                                                          ..
# ...

# %% [markdown]
# **The 'Switch to order menu' column contains only one type of value. I believe dropping it will not impact model building and prediction.**

# %%
# drop the feature
df.drop('Switch to order menu', axis=1, inplace=True)

# %%
# Show the statistical summary of data
df.describe()
# Out:
#        Average Cost for two  Price range  Aggregate rating         Votes
# count           9551.000000  9551.000000       9551.000000   9551.000000
# mean            1199.210763     1.804837          2.666370    156.909748
# std            16121.183073     0.905609          1.516378    430.169145
# min                0.000000     1.000000          0.000000      0.000000
# 25%              250.000000     1.000000          2.500000      5.000000
# 50%              400.000000     2.000000          3.200000     31.000000
# 75%              700.000000     2.000000          3.700000    131.000000
# max           800000.000000     4.000000          4.900000  10934.000000

# %% [markdown]
# **Upon observation:**
#
# **- The counts of all columns are the same, indicating that there are no missing values.**
#
# **- In some columns, such as Average Cost for two, and Votes, the mean value is greater than the median value, suggesting that the data is positively skewed (right-skewed).**
#
# **- In other columns, like Aggregate rating, Price range, the mean value is lesser than the median, indicating that the data is negatively skewed.**
#
# **- A review suggests the presence of some outliers, based on the differences between the 75th percentile and the maximum value.**

# %%
# Show the statistical summary of  categorical data
df.describe(include='object').T
# Out:
#                     count unique                         top  freq
# City                 9551    141                   New Delhi  5473
# Address              9551   8918            Sector 41, Noida    11
# Locality             9551   1208             Connaught Place   122
# Locality Verbose     9551   1265  Connaught Place, New Delhi   122
# Cuisines             9551   1825                North Indian   945
# Currency             9551     12          Indian Rupees(Rs.)  8652
# Has Table booking    9551      2                          No  8393
# Has Online delivery  9551      2                          No  7100
# Is delivering now    9551      2                          No  9517
# Rating color         9551      6                      Orange  3737
# Rating text          9551      6                     Average  3737
# Country              9551     15                       India  8652

# %%
# Show the size of the dataset
df.size
# Out:
# 152816

# %% [markdown]
# # EDA

# %%
figure, axs = plt.subplots(1, 2, figsize=(15, 6))

sns.countplot(x=df['Has Table booking'], color='yellow',ax=axs[0])
axs[0].set_title('Class Distribution')
axs[0].set_xlabel('Table booking')
axs[0].set_ylabel('Count')

type_count = df['Has Table booking'].value_counts()
type_count.plot.pie(ax=axs[1], autopct='%1.1f%%', explode=(0.03,0), colors=['red', 'yellow'])
axs[1].set_title('Class Distribution')


plt.show()

# %% [markdown]
# **Observation,**
#
# **- The count plot show that many of resturants doest not have option for pre booked a table for lunch/dinner.**
#
# **- The pie plot shows that the 87.9% resturants are not pre booked a table and only 12.1% resturants are booked a table of total zomato resturants.**

# %%
figure, axs = plt.subplots(1, 2, figsize=(15, 6))

sns.countplot(x=df['Has Online delivery'], color='y',ax=axs[0])
axs[0].set_title('Class Distribution')
axs[0].set_xlabel('Online delivery')
axs[0].set_ylabel('Count')

type_count = df['Has Online delivery'].value_counts()
type_count.plot.pie(ax=axs[1], autopct='%1.1f%%', explode=(0.03,0), colors=['blue', 'green'])
axs[1].set_title('Class Distribution')


plt.show()

# %% [markdown]
# **Observation,**
#
# **- The count plot shows that, most of the resturants do not have online delivery.**
#
# **- The pie plot shows that, 74.3% resturants have offline delivery and only 25.7% resturants have online delivery of total zomato resturant.**

# %%
figure, axs = plt.subplots(1, 2, figsize=(15, 6))

sns.countplot(x=df['Is delivering now'], color='blue',ax=axs[0])
axs[0].set_title('Class Distribution')
axs[0].set_xlabel('Delivery')
axs[0].set_ylabel('Count')

type_count = df['Is delivering now'].value_counts()
type_count.plot.pie(ax=axs[1], autopct='%1.1f%%', explode=(0.03,0), colors=['yellow', 'green'])
axs[1].set_title('Class Distribution')


plt.show()

# %% [markdown]
# **Observation,**
#
# **- the count plot shows that, most of the resturant are not delivering now only few resturants are delivering now.**
#
# **- the pie plot shows the percentage, 99.6% resturants do not delivery any food now and only 0.4% resturants are delivered food right now.**

# %%
figure, axs = plt.subplots(1, 2, figsize=(15, 6))

sns.countplot(x=df['Currency'], color='y', ax=axs[0])
axs[0].set_xlabel('currency')
axs[0].tick_params(axis='x', rotation=45)

sns.countplot(x=df['Rating text'], color='red', ax=axs[1])
axs[1].set_xlabel('Text')

plt.tight_layout()
plt.show()

# %% [markdown]
# **Observation,**
#
# **- from the left plot, observe that Indian Rupee(Rs.) has a significantly higher count, it suggests that most restaurants in our dataset operate within that currency.**
#
# **- from the right plot, observe that Average rating has a significantly higher count, it indicates that most of the resturants are average food quality,service etc.**

# %%
figure, axs = plt.subplots(1, 2, figsize=(15, 6))

sns.countplot(x=df['Aggregate rating'], color='g', ax=axs[0])
axs[0].set_xlabel('Rating')
axs[0].tick_params(axis='x', rotation=45)

sns.countplot(x=df['Price range'], color='b', ax=axs[1])
axs[1].set_xlabel('Price')

plt.tight_layout()
plt.show()

# %% [markdown]
# **Observation,**
#
# **- From the left plot, observe that 0 rating are significantly high count, it indicates that most of the resturants are under rated.**
#
# **- From the right plot, observe that low price range are significantly high. it indicates that most of the resturants have low price range.**

# %%
figure, axs = plt.subplots(1, 2, figsize=(15, 6))

sns.barplot(x=df['Aggregate rating'], color='yellow', ax=axs[0], hue=df['Price range'])
axs[0].tick_params(axis='x', rotation=45)

sns.barplot(x=df['Aggregate rating'], color='red', ax=axs[1], hue=df['Rating text'])

plt.tight_layout()
plt.show()

# %% [markdown]
# **Observation,**
#
# **- From left plot we observe that, the restaurants with high prices also have high ratings.it may indicate that customers feel they receive better value or quality at that price point.**
#
# **- From right plot shows that, positive sentiment categories have higher ratings it indicates the idea that satisfied customers tend to rate restaurants better.**

# %%
figure, axs = plt.subplots(1, 2, figsize=(15, 6))

sns.scatterplot(x=df['Aggregate rating'], y=df['Price range'],color='blue', ax=axs[0])
axs[0].tick_params(axis='x', rotation=45)

sns.scatterplot(x=df['Aggregate rating'],y=df['Average Cost for two'], color='black', ax=axs[1])

plt.tight_layout()
plt.show()

# %%
figure, axs = plt.subplots(1, 2, figsize=(15, 6))

sns.barplot(x=df['Has Online delivery'], y=df['Aggregate rating'],color='g', ax=axs[0])
axs[0].tick_params(axis='x', rotation=45)

sns.barplot(x=df['Has Table booking'],y=df['Average Cost for two'], color='b', ax=axs[1])

plt.tight_layout()
plt.show()

# %% [markdown]
# **Observation,**
#
# **- From the plot, we conclude that restaurants with an online delivery system tend to receive higher ratings.**
#
# **- From the right plot, we can conclude that restaurants that accept pre-table bookings generally have a higher average cost for two customers.**

# %%
figure, axs = plt.subplots(1, 2, figsize=(15, 6))

sns.barplot(x=df['Has Online delivery'], y=df['Price range'],color='yellow', ax=axs[0])
axs[0].tick_params(axis='x', rotation=45)

sns.barplot(x=df['Is delivering now'],y=df['Aggregate rating'], color='red', ax=axs[1])

plt.tight_layout()
plt.show()

# %% [markdown]
# **Observations,**
#
# **- From the plot, we can conclude that restaurants with online delivery systems have a higher price range compared to others.**
#
# **- From the right plot, we can conclude that restaurants currently offering delivery have a higher aggregate rating from customers.**

# %%
figure, axs = plt.subplots(1, 2, figsize=(15, 6))

sns.barplot(x=df['Rating text'], y=df['Average Cost for two'],color='skyblue', ax=axs[0])
axs[0].tick_params(axis='x', rotation=45)

sns.regplot(x=df['Average Cost for two'],y=df['Aggregate rating'], color='grey', ax=axs[1])

plt.tight_layout()
plt.show()

# %% [markdown]
# **Observation,**
#
# **- From the plot, we can conclude that restaurants with excellent ratings have a higher average cost for two people.**
#
# **- From the right plot, we can conclude that restaurants with high customer ratings also have a higher average cost for two. This shows an upward trend and a linear relationship.**

# %%
plt.figure(figsize=(15,10))
p=1

for col in df.select_dtypes(include=['float64','int64']).columns:
    if p < 10:
        ax=plt.subplot(3,3,p)
        sns.distplot(x=df[col])
        plt.title(f'Distribution of {col}')
    p+=1
plt.tight_layout()

# %% [markdown]
# **- By the distribution plot, we see that there some of features are not normally distributed.**

# %% [markdown]
# **Correlation Analysis**

# %%
df_corr = df.corr().abs()
plt.figure(figsize=(12,6))
sns.heatmap(df_corr, annot=True, annot_kws={'size' : 6}, cmap='Blues')
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# **There is no multicolinearity seen by heat map**

# %% [markdown]
# **CHECK OUTLIER**

# %%
plt.figure(figsize=(15, 10))
p=1
for col in df.select_dtypes(include=['float64','int64']).columns:
    if p < 12 :
        ax = plt.subplot(4,4,p)
        sns.boxplot(df[col])
    p +=1    
    
plt.tight_layout()

# %% [markdown]
# **- The box plot reveals that some columns contain outliers. To ensure model stability and performance, we need to remove these outliers or unnecessary data from the dataset. Therefore, we will use the z-score method to eliminate them.**

# %%
from scipy import stats


# Calculate Z-scores
z_scores = np.abs(stats.zscore(df[['Aggregate rating', 'Votes']]))

# Identify outliers
outlier_mask = (z_scores > 3).any(axis=1)

# Remove outliers
x = df[~outlier_mask]


# Check the number of rows after removing outliers
print("Number of rows after removing outliers:", x.shape[0])
# Out:
# Number of rows after removing outliers: 9378

# %%
print('Old Dtaframe size : ',df.shape[0])
print('New Dtaframe size : ',x.shape[0])
# Out:
# Old Dtaframe size :  9551
# New Dtaframe size :  9378

# %%
print('Data Loss Percentage : ',((df.shape[0]-x.shape[0])/df.shape[0])*100)
# Out:
# Data Loss Percentage :  1.8113286566851639

# %% [markdown]
# **CHECK SKEWNESS**

# %%
x.skew()
# Out:
# Average Cost for two    38.623972
# Price range              0.927646
# Aggregate rating        -0.942181
# Votes                    3.199653
# dtype: float64

# %% [markdown]
# **- we check the skewness only for numerical feature not for categorical.**
#
# **- Aggregate rating and Votes numerical columns has skewness.So we remove it for normal distribution.**
#
# **- Average Cost for two and Price range are the target variable so no need to check skewness.**

# %%
x['Aggregate rating'] = np.square(x['Aggregate rating'])

# %%
x['Votes'] = np.sqrt(x['Votes'])

# %%
x.skew()
# Out:
# Average Cost for two    38.623972
# Price range              0.927646
# Aggregate rating        -0.216192
# Votes                    0.164126
# dtype: float64

# %% [markdown]
# **- Based on observation, there is no skewness present in feature.**

# %% [markdown]
# **Encode categorical feature**

# %%
from sklearn.preprocessing import LabelEncoder
LE = LabelEncoder()
for i in x.columns:
    if x[i].dtypes == 'object':
        x[i] = LE.fit_transform(x[i].values.reshape(-1,1))
        
        
x.head()
# Out:
#    City  Address  Locality  Locality Verbose  Cuisines  Average Cost for two  \
# 0    73     8524       163               164       886                  1100
# 1    73     5927       574               582      1070                  1200
# 2    75     4582       297               303      1620                  4000
# 3    75     8529       834               847      1085                  1500
# 4    75     8528       834               847      1081                  1500
#
#    Currency  Has Table booking  Has Online delivery  Is delivering now  \
# 0         0                  1                    0                  0
# 1         0                  1                    0                  0
# 2         0                  1                    0                  0
# 3         0                  0                    0                  0
# 4         0                  1                    0                  0
#
# ...

# %%
X = x.drop(columns=['Average Cost for two','Price range'])
y1 = x['Average Cost for two']
y2 = x['Price range']

# %% [markdown]
# **FEATURE SCALING**

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
x1 = pd.DataFrame(scaler.fit_transform(X), columns=X.columns)

# %% [markdown]
# **To check Multicolinearity using VIF method**

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
f = x1.columns
d = {'Feature': f}
d['VIF'] = [variance_inflation_factor(x1.values, i) for i in range(len(f))]
df1 = pd.DataFrame(d)

df1
# Out:
#                 Feature          VIF
# 0                  City    10.210784
# 1               Address     4.275342
# 2              Locality  4729.342071
# 3      Locality Verbose  4577.752157
# 4              Cuisines     4.526254
# 5              Currency    13.788815
# 6     Has Table booking     1.267351
# 7   Has Online delivery     1.581068
# 8     Is delivering now     1.017218
# 9      Aggregate rating    12.247451
# 10         Rating color     5.472983
# 11          Rating text     2.388853
# 12                Votes    15.007067
# 13              Country     3.731955

# %%
x1.drop('Locality Verbose', axis=1, inplace=True)

# %%
f = x1.columns
d = {'Feature': f}
d['VIF'] = [variance_inflation_factor(x1.values, i) for i in range(len(f))]
df1 = pd.DataFrame(d)

df1
# Out:
#                 Feature        VIF
# 0                  City   9.874426
# 1               Address   4.274985
# 2              Locality   5.367235
# 3              Cuisines   4.509992
# 4              Currency  13.570367
# 5     Has Table booking   1.267323
# 6   Has Online delivery   1.579367
# 7     Is delivering now   1.017216
# 8      Aggregate rating  12.237116
# 9          Rating color   5.469294
# 10          Rating text   2.388725
# 11                Votes  14.998992
# 12              Country   3.731791

# %%
x1.drop('Votes', axis=1, inplace=True)

# %%
f = x1.columns
d = {'Feature': f}
d['VIF'] = [variance_inflation_factor(x1.values, i) for i in range(len(f))]
df1 = pd.DataFrame(d)

df1
# Out:
#                 Feature        VIF
# 0                  City   9.845288
# 1               Address   4.237847
# 2              Locality   5.362058
# 3              Cuisines   4.487768
# 4              Currency  13.558864
# 5     Has Table booking   1.211717
# 6   Has Online delivery   1.482283
# 7     Is delivering now   1.016951
# 8      Aggregate rating   4.350409
# 9          Rating color   5.399493
# 10          Rating text   2.363519
# 11              Country   3.655738

# %%
x1.drop('Currency', axis=1, inplace=True)

# %%
f = x1.columns
d = {'Feature': f}
d['VIF'] = [variance_inflation_factor(x1.values, i) for i in range(len(f))]
df1 = pd.DataFrame(d)

df1
# Out:
#                 Feature       VIF
# 0                  City  8.845108
# 1               Address  3.998397
# 2              Locality  5.130599
# 3              Cuisines  4.139102
# 4     Has Table booking  1.210745
# 5   Has Online delivery  1.481541
# 6     Is delivering now  1.016950
# 7      Aggregate rating  4.020795
# 8          Rating color  5.210997
# 9           Rating text  2.339398
# 10              Country  3.611500

# %% [markdown]
# **- Upon reviewing the VIF values, all values were found to be less than 10, indicating that there is no multicollinearity present.**
#
# **- Now our data is clear.Now we proceed to build the model using ML algorithms.**

# %% [markdown]
# # Model Building(Average cost for two)

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor,GradientBoostingRegressor,ExtraTreesRegressor,AdaBoostRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.linear_model import Ridge
from sklearn.model_selection import GridSearchCV,cross_val_score,KFold
from sklearn.metrics import r2_score,mean_squared_error,mean_absolute_error

# %%
maxAccu = 0
maxRS = 0

for i in range(1,150):
    x_train, x_test, y_train, y_test = train_test_split(x1, y1, test_size=0.25, random_state=i)
    rf = RandomForestRegressor()
    rf.fit(x_train,y_train)
    pred = rf.predict(x_test)
    r = r2_score(y_test,pred)
    if r>maxAccu:
        maxAccu=r
        maxRS=i
print('Maximum accuracy is ', maxAccu, 'on random state ', maxRS)
# Out:
# Maximum accuracy is  0.8961024716454149 on random state  9

# %%
x_train, x_test, y_train, y_test = train_test_split(x1, y1, test_size=0.25, random_state=maxRS)

# %%
def metric(reg, x_train, x_test, y_train, y_test):
    train_accu = r2_score(reg.predict(x_train),y_train)*100
    y_pred = reg.predict(x_test)
    test_accu = r2_score(y_test, y_pred) * 100
    mse = mean_squared_error(y_test, y_pred)
    mae = mean_absolute_error(y_test, y_pred)
    rmse = np.sqrt(mean_squared_error(y_test,y_pred))
    return train_accu, test_accu, mse, mae, rmse

# %%
def cross(reg, x_train, y_train):
    k = KFold(n_splits=5)
    score = cross_val_score(reg, x_train, y_train, cv=k, scoring='r2')
    print("Cross Validation Score : {}".format(score))
    print("Average Cross Validation Score : {}".format(score.mean()))
    print("\n------------------") 
    difference = (r2_score(y_test,y_pred) - score.mean())
    return difference

# %%
models = [
    ('AdaBoost Regressor', AdaBoostRegressor()),
    ('DecisionTree Regressor', DecisionTreeRegressor()),
    ('Random Forest Regressor', RandomForestRegressor()),
    ('Gradient Boosting Regressor', GradientBoostingRegressor()),
    ('ExtraTrees Regressor', ExtraTreesRegressor()),
    ('KNearest Regressor', KNeighborsRegressor()),
    ('Ridge Regression', Ridge())
]

# %% [markdown]
# # Model Evalution

# %%
for name, reg in models:
    reg.fit(x_train, y_train)
    y_pred = reg.predict(x_test)
    
    train_accu, test_accu, mse, mae, rmse = metric(reg, x_train, x_test, y_train, y_test)
    
    print(f'{name} Metrics:')
    print('---------------------------------------------------')
    print(f'Train Accuracy: {train_accu:.2f}%')
    print(f'Test Accuracy: {test_accu:.2f}%')
    print('Mean Squared Error:', mse)
    print('Mean Absolute Error:', mae)
    print('Root Mean Squared Error:', rmse)
    
    difference = cross(reg, x_train, y_train)
    print(f"Difference between test accuracy and average cross-validation score: {difference:.4f}")
    print("="*50)
# Out:
# AdaBoost Regressor Metrics:
# ---------------------------------------------------
# Train Accuracy: 87.17%
# Test Accuracy: 72.74%
# Mean Squared Error: 13956756.477474255
# Mean Absolute Error: 739.8617015088364
# Root Mean Squared Error: 3735.8742587879287
# Cross Validation Score : [  0.57390764  -6.56058771  -1.9003072  -21.5952079    0.31068591]
# Average Cross Validation Score : -5.834301852715552
#
# ------------------
# Difference between test accuracy and average cross-validation score: 6.5617
# ...
# DecisionTree Regressor Metrics:
# ---------------------------------------------------
# Train Accuracy: 100.00%
# Test Accuracy: -304.41%
# Mean Squared Error: 207078371.2895996
# Mean Absolute Error: 727.7161336176262
# Root Mean Squared Error: 14390.217902783806
# Cross Validation Score : [ -0.37430496 -10.89606773  -2.07810438   0.42343637   0.40318513]
# Average Cross Validation Score : -2.5043711134666786
#
# ------------------
# ...

# %% [markdown]
# **By evaluation,**
#
#
#    **- From the model evaluation, we observe that Random Forest perform well and provide precise results and stands out as the best model for our dataset.**
#
#
#
# **** Here are the reasons why:***
#
#    **-  Random Forest Regressor with a test accuracy of 81.69% and a reasonable average cross-validation score of -3.01. It demonstrates strong performance and generalization capabilities, making it the most robust choice among the models listed.**
#
#
#    **-  Random Forest Regressor has a difference of 3.8, which is better than other models, indicating it generalizes well and is less likely to be overfitting.**

# %% [markdown]
# # Tuning the best model

# %%
para = {
    'n_estimators': [120, 100],
    'criterion' : ['squared_error', 'friedman_mse'],
    'min_samples_split' : [2,1],
    'min_samples_leaf' : [2,1],
    'max_features' : ['sqrt', 'log2']
}

# %%
ac = GridSearchCV(RandomForestRegressor(), param_grid=para, cv=5, scoring='r2')
ac.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestRegressor(),
#              param_grid={'criterion': ['squared_error', 'friedman_mse'],
#                          'max_features': ['sqrt', 'log2'],
#                          'min_samples_leaf': [2, 1],
#                          'min_samples_split': [2, 1],
#                          'n_estimators': [120, 100]},
#              scoring='r2')

# %%
ac.best_params_
# Out:
# {'criterion': 'squared_error',
#  'max_features': 'sqrt',
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'n_estimators': 120}

# %%
final = RandomForestRegressor(criterion= 'squared_error', max_features= 'sqrt', min_samples_leaf= 1, min_samples_split= 2, n_estimators= 120)
final.fit(x_train,y_train)
prediction = final.predict(x_test)
print('Testing Accuracy : {:.2f} %'.format(round(r2_score(y_test, prediction) * 100, 2)))
print('-----------------------------------------------')
print('Mean Squared Error:',mean_squared_error(y_test,prediction))
print('Mean Absolute Error:', mean_absolute_error(y_test,prediction))
print('Root Mean Squared Error:', np.sqrt(mean_squared_error(y_test,prediction)))
# Out:
# Testing Accuracy : 84.12 %
# -----------------------------------------------
# Mean Squared Error: 8132520.448147445
# Mean Absolute Error: 456.5830421024131
# Root Mean Squared Error: 2851.757431505605

# %% [markdown]
# # Model Building(Price range)

# %%
maxAccu = 0
maxRS = 0

for i in range(1,150):
    x_train_1, x_test_1, y_train_1, y_test_1 = train_test_split(x1, y2, test_size=0.25, random_state=i)
    rf = RandomForestRegressor()
    rf.fit(x_train_1,y_train_1)
    pred = rf.predict(x_test_1)
    r = r2_score(y_test_1,pred)
    if r>maxAccu:
        maxAccu=r
        maxRS=i
print('Maximum accuracy is ', maxAccu, 'on random state ', maxRS)
# Out:
# Maximum accuracy is  0.6404454553268825 on random state  62

# %%
x_train_1, x_test_1, y_train_1, y_test_1 = train_test_split(x1, y2, test_size=0.25, random_state=maxRS)

# %%
def eval_mat(reg, x_train_1, x_test_1, y_train_1, y_test_1):
    train_accu = r2_score(reg.predict(x_train_1),y_train_1)*100
    y_pred_1 = reg.predict(x_test_1)
    test_accu = r2_score(y_test_1, y_pred_1) * 100
    mse = mean_squared_error(y_test_1, y_pred_1)
    mae = mean_absolute_error(y_test_1, y_pred_1)
    rmse = np.sqrt(mean_squared_error(y_test_1, y_pred_1))
    return train_accu, test_accu, mse, mae, rmse

# %%
def c_val(reg, x_train_1, y_train_1):
    k = KFold(n_splits=5)
    score = cross_val_score(reg, x_train_1, y_train_1, cv=k, scoring='r2')
    print("Cross Validation Score : {}".format(score))
    print("Average Cross Validation Score : {}".format(score.mean()))
    print("\n------------------") 
    difference = (r2_score(y_test_1, y_pred_1) - score.mean())
    return difference

# %%
model = [
    ('AdaBoost Regressor', AdaBoostRegressor()),
    ('DecisionTree Regressor', DecisionTreeRegressor()),
    ('Random Forest Regressor', RandomForestRegressor()),
    ('Gradient Boosting Regressor', GradientBoostingRegressor()),
    ('ExtraTrees Regressor', ExtraTreesRegressor()),
    ('KNearest Regressor', KNeighborsRegressor()),
    ('Ridge Regression', Ridge())
]

# %%
for name, reg in model:
    reg.fit(x_train_1, y_train_1)
    y_pred_1 = reg.predict(x_test_1)
    
    train_accu, test_accu, mse, mae, rmse = eval_mat(reg, x_train_1, x_test_1, y_train_1, y_test_1)
    
    print(f'{name} Metrics:')
    print('---------------------------------------------------')
    print(f'Train Accuracy: {train_accu:.2f}%')
    print(f'Test Accuracy: {test_accu:.2f}%')
    print('Mean Squared Error:', mse)
    print('Mean Absolute Error:', mae)
    print('Root Mean Squared Error:', rmse)
    
    difference = c_val(reg, x_train_1, y_train_1)
    print(f"Difference between test accuracy and average cross-validation score: {difference:.4f}")
    print("="*50)
# Out:
# AdaBoost Regressor Metrics:
# ---------------------------------------------------
# Train Accuracy: -102.50%
# Test Accuracy: 42.60%
# Mean Squared Error: 0.46170725621641484
# Mean Absolute Error: 0.5805270819874664
# Root Mean Squared Error: 0.6794904386497391
# Cross Validation Score : [0.40337165 0.43853235 0.42484637 0.41926127 0.40411796]
# Average Cross Validation Score : 0.41802591948956247
#
# ------------------
# Difference between test accuracy and average cross-validation score: 0.0080
# ...
# DecisionTree Regressor Metrics:
# ---------------------------------------------------
# Train Accuracy: 99.99%
# Test Accuracy: 29.27%
# Mean Squared Error: 0.5689173181710495
# Mean Absolute Error: 0.4530206112295665
# Root Mean Squared Error: 0.7542660791597681
# Cross Validation Score : [0.24898603 0.21960466 0.33313607 0.2402194  0.22477003]
# Average Cross Validation Score : 0.2533432354951328
#
# ------------------
# ...

# %% [markdown]
# **By evaluation,**
#
#
#    **- From the model evaluation, we observe that Random Forest perform well and provide precise results and stands out as the best model for our dataset.**
#
#
#
# **** Here are the reasons why:***
#
#    **-  Random Forest Regressor with a test accuracy of 64.02% and a reasonable average cross-validation score of 0.59. It demonstrates strong performance and generalization capabilities, making it the most robust choice among the models listed.**
#
#
#    **-  Random Forest Regressor has a difference of 0.04, which is better than other models, indicating it generalizes well and is less likely to be overfitting.**

# %% [markdown]
# # Model tuning

# %%
n = {
    'n_estimators': [120, 100],
    'criterion' : ['squared_error', 'friedman_mse'],
    'min_samples_split' : [2,1],
    'min_samples_leaf' : [2,1],
    'max_features' : ['sqrt', 'log2']
}

# %%
p = GridSearchCV(RandomForestRegressor(), param_grid=n, cv=5, scoring='r2')
p.fit(x_train_1,y_train_1)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestRegressor(),
#              param_grid={'criterion': ['squared_error', 'friedman_mse'],
#                          'max_features': ['sqrt', 'log2'],
#                          'min_samples_leaf': [2, 1],
#                          'min_samples_split': [2, 1],
#                          'n_estimators': [120, 100]},
#              scoring='r2')

# %%
p.best_params_
# Out:
# {'criterion': 'friedman_mse',
#  'max_features': 'log2',
#  'min_samples_leaf': 2,
#  'min_samples_split': 2,
#  'n_estimators': 120}

# %%
p_final = RandomForestRegressor(criterion= 'friedman_mse', max_features= 'log2', min_samples_leaf= 2, min_samples_split= 2, n_estimators= 120)
p_final.fit(x_train_1,y_train_1)
predict = p_final.predict(x_test_1)
print('Testing Accuracy : {:.2f} %'.format(round(r2_score(y_test_1, predict) * 100, 2)))
print('-----------------------------------------------')
print('Mean Squared Error:',mean_squared_error(y_test_1,predict))
print('Mean Absolute Error:', mean_absolute_error(y_test_1,predict))
print('Root Mean Squared Error:', np.sqrt(mean_squared_error(y_test_1,predict)))
# Out:
# Testing Accuracy : 61.94 %
# -----------------------------------------------
# Mean Squared Error: 0.3061606191333261
# Mean Absolute Error: 0.4236053950610848
# Root Mean Squared Error: 0.5533178283168961

# %% [markdown]
# # Save the model

# %%
import joblib
joblib.dump(final,'Zomato_Data_Analysis.pkl')
# Out:
# ['Zomato_Data_Analysis.pkl']

# %%
import joblib
joblib.dump(p_final,'Zomato_Data_Analysis.pkl')
# Out:
# ['Zomato_Data_Analysis.pkl']
